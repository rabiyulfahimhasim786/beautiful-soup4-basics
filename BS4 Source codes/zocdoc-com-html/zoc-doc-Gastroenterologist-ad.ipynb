# %%
import requests, bs4
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://www.zocdoc.com'
PAGE = 'gastroenterologists/3'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!doctype html>
#     <html lang="en">
#         <head>
#             <meta name="msapplication-TileImage" content="/images/rebrand/favicon/favicon_large.png" />
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />
# <meta name="format-detection" content="telephone=no" />
#             <link rel="shortcut icon" type="image/x-icon" href="https://www.zocdoc.com/favicon.ico" sizes="32x32" />
# <link rel="dns-prefetch" href="//api.zocdoc.com" />
# <link rel="dns-prefetch" href="//www.zocdoc.com" />
# <link rel="preconnect" href="https://api.zocdoc.com" />
# <link rel="preconnect" href="https://www.zocdoc.com" />
# <link rel="dns-prefetch" href="//dd.zocdoc.com" />
# <link rel="preconnect" href="https://dd.zocdoc.com" />
# <link rel="dns-prefetch" href="//js.captcha-display.com" />
# <link rel="preconnect" href="https://js.captcha-display.com" />
# ...

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
#HOST = 'https://www.zocdoc.com'
#PAGE = 'gastroenterologists/2'
web_page = 'https://www.zocdoc.com/search?address=Houston%2C+TX&after_5pm=false&before_10am=false&city=Houston&day_filter=AnyDay&dr_specialty=106&filters=%7B%7D&gender=-1&insurance_carrier=&insurance_plan=-1&language=-1&latitude=29.7604267&locationType=placemark&longitude=-95.3698028&offset=0&reason_visit=386&searchQueryGuid=b000b76a-cd6d-4630-a3bf-185259b9e30f&searchType=specialty&search_query=Gastroenterologist&sees_children=false&sort_type=Default&state=TX&visitType=inPersonVisit'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
    #(r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    (r := session.get(f'{web_page}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!doctype html>
#     <html lang="en">
#         <head>
#             <meta name="msapplication-TileImage" content="/images/rebrand/favicon/favicon_large.png" />
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />
# <meta name="format-detection" content="telephone=no" />
#             <link rel="shortcut icon" type="image/x-icon" href="https://www.zocdoc.com/favicon.ico" sizes="32x32" />
# <link rel="dns-prefetch" href="//api.zocdoc.com" />
# <link rel="dns-prefetch" href="//www.zocdoc.com" />
# <link rel="preconnect" href="https://api.zocdoc.com" />
# <link rel="preconnect" href="https://www.zocdoc.com" />
# <link rel="dns-prefetch" href="//dd.zocdoc.com" />
# <link rel="preconnect" href="https://dd.zocdoc.com" />
# <link rel="dns-prefetch" href="//js.captcha-display.com" />
# <link rel="preconnect" href="https://js.captcha-display.com" />
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="/images/rebrand/favicon/favicon_large.png" name="msapplication-TileImage"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.zocdoc.com/favicon.ico" rel="shortcut icon" sizes="32x32" type="image/x-icon"/>
#   <link href="//api.zocdoc.com" rel="dns-prefetch"/>
#   <link href="//www.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://api.zocdoc.com" rel="preconnect"/>
#   <link href="https://www.zocdoc.com" rel="preconnect"/>
#   <link href="//dd.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://dd.zocdoc.com" rel="preconnect"/>
#   <link href="//js.captcha-display.com" rel="dns-prefetch"/>
#   <link href="https://js.captcha-display.com" rel="preconnect"/>
#   <link href="//d1uhlocgth3qyq.cloudfront.net" rel="dns-prefetch"/>
# ...

# %%
for item in soup.find_all('img'):
	print(item['src'])
# Out:
# //d1k13df5m14swc.cloudfront.net/photos/Dr-Murtaza-Arif-MD-279905-circle_medium__v2__.png
# //d2uur722ua7fvv.cloudfront.net/photos/Dr-David-S-Wolf-MD-72941-circle_medium__v1__.png
# //d1k13df5m14swc.cloudfront.net/photos/Dr-Ali-Hashmi-MD-331212-circle_medium__v1__.png
# //d3wnzga3fpd9a.cloudfront.net/photos/Dr-Avais-Chatha-MD-280008-circle_medium__v7__.png
# //d1k13df5m14swc.cloudfront.net/photos/Dr-Shabbir-Husain-Jamali-MD-289694-circle_medium__v1__.png
# //d1k13df5m14swc.cloudfront.net/photos/Dr-Svetang-Desai-MD-338686-circle_medium__v1__.png
# //d3wnzga3fpd9a.cloudfront.net/photos/Sean-Yu-PA-326463-circle_medium__v1__.png
# //d1k13df5m14swc.cloudfront.net/photos/Dr-John-Dugan-MD-177742-circle_medium__v1__.png
# //d3wnzga3fpd9a.cloudfront.net/photos/Dr-Muhammad-Behzad-Zafar-MD-135281-circle_medium.png
# //d2uur722ua7fvv.cloudfront.net/photos/Dr-Ravi-Moparty-MD-22470-circle_medium__v1__.png
# //d1k13df5m14swc.cloudfront.net/photos/Dr-Murtaza-Arif-MD-279905-circle_medium__v2__.png
# ...

# %%
for item in soup.find_all('img'):
    items = (item['src'])
    b = 'https:'+items
    print(b)
# Out:
# https://d1k13df5m14swc.cloudfront.net/photos/Dr-Murtaza-Arif-MD-279905-circle_medium__v2__.png
# https://d2uur722ua7fvv.cloudfront.net/photos/Dr-David-S-Wolf-MD-72941-circle_medium__v1__.png
# https://d1k13df5m14swc.cloudfront.net/photos/Dr-Ali-Hashmi-MD-331212-circle_medium__v1__.png
# https://d3wnzga3fpd9a.cloudfront.net/photos/Dr-Avais-Chatha-MD-280008-circle_medium__v7__.png
# https://d1k13df5m14swc.cloudfront.net/photos/Dr-Shabbir-Husain-Jamali-MD-289694-circle_medium__v1__.png
# https://d1k13df5m14swc.cloudfront.net/photos/Dr-Svetang-Desai-MD-338686-circle_medium__v1__.png
# https://d3wnzga3fpd9a.cloudfront.net/photos/Sean-Yu-PA-326463-circle_medium__v1__.png
# https://d1k13df5m14swc.cloudfront.net/photos/Dr-John-Dugan-MD-177742-circle_medium__v1__.png
# https://d3wnzga3fpd9a.cloudfront.net/photos/Dr-Muhammad-Behzad-Zafar-MD-135281-circle_medium.png
# https://d2uur722ua7fvv.cloudfront.net/photos/Dr-Ravi-Moparty-MD-22470-circle_medium__v1__.png
# ...

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-name-full'})

doctor_n = []

for title in movies_html:
 doctor_n.append(title.text.strip())
print(doctor_n)
# Out:
# ['Murtaza Arif', 'David S. Wolf', 'Ali Hashmi', 'Avais Chatha', 'Shabbir-Husain Jamali', 'Svetang Desai', 'Sean Yu', 'John Dugan', 'Muhammad Behzad Zafar', 'Ravi Moparty', 'Murtaza Arif', 'Alejandro Mora', "Phuong 'Amy' Pham", 'Bridget Nwaogu', 'Beatrice Gyebi', "Bach-Cuc 'Daisy' Tran", 'Ravi Moparty']

# %%
len(doctor_n)
# Out:
# 17

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'doctor-card-info-specialty'})

specialty = []

for title in movies_html:
 specialty.append(title.text.strip())
print(specialty)
# Out:
# ['Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Physician Assistant', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Internist', 'Family Nurse Practitioner', 'Nurse Practitioner', 'Nurse Practitioner', 'Physician Assistant', 'Gastroenterologist']

# %%
len(specialty)
# Out:
# 17

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'doctor-card-info-location'})

location = []

for title in movies_html:
 location.append(title.text.strip())
print(location)
# Out:
# ['1331 W Grand Pkwy N, 350, Katy, TX 77493', '1701 Sunset Blvd, Houston, TX 77005', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', 'Houston Methodist Gastroenterology Associates16651 Southwest Fwy, Ste 250, Sugarland, TX 77479', 'Village Medical @ Walgreens - Northshore500 Maxey Rd, Ste A, Houston, TX 77013', '1701 Sunset Blvd, Houston, TX 77005', '1701 Sunset Blvd, Houston, TX 77005', '8901 FM 1960 West Rd, Ste 204, Humble, TX 77338', '1331 W Grand Pkwy N, 350, Katy, TX 77493', '2244 West Holcombe Blvd, Houston, TX 77030', 'Northside Village2221 Fulton St, Houston, TX 77009', 'Village Medical @ Walgreens - Pasadena Northwest101 W Southmore Ave, Pasadena, TX 77502', '12611 S Gessner Rd, Houston, TX 77071', 'Memorial Clinical Associates16001 Park Ten Pl, Houston, TX 77084', '25410 Interstate 45 N, Suite 100, Spring, TX 77386']

# %%
len(location)
# Out:
# 17

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-name-suffix'})

degree = []

for title in movies_html:
 degree.append(title.text.strip())
print(degree)
# Out:
# [', MD', ', MD', ', MD', ', MD', ', MD', ', MD', ', PA', ', MD', ', MD', ', MD', ', MD', ', MD', ', NP', ', NP', ', NP', ', PA', ', MD']

# %%
len(degree)
# Out:
# 17

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-location-city'})

city = []

for title in movies_html:
 city.append(title.text.strip())
print(city)
# Out:
# ['Katy', 'Houston', 'Tomball', 'Tomball', 'Tomball', 'Sugarland', 'Houston', 'Houston', 'Houston', 'Humble', 'Katy', 'Houston', 'Houston', 'Pasadena', 'Houston', 'Houston', 'Spring']

# %%
len(city)
# Out:
# 17

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-location-state'})

state = []

for title in movies_html:
 state.append(title.text.strip())
print(state)
# Out:
# ['TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX', 'TX']

# %%
len(state)
# Out:
# 17

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-location-zip'})

postal_code = []

for title in movies_html:
 postal_code.append(title.text.strip())
print(postal_code)
# Out:
# ['77493', '77005', '77375', '77375', '77375', '77479', '77013', '77005', '77005', '77338', '77493', '77030', '77009', '77502', '77071', '77084', '77386']

# %%
len(postal_code)
# Out:
# 17

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-location-address'})

street_name = []

for title in movies_html:
 street_name.append(title.text.strip())
print(street_name)
# Out:
# ['1331 W Grand Pkwy N, 350', '1701 Sunset Blvd', '421 School St, Ste. 110', '421 School St, Ste. 110', '421 School St, Ste. 110', '16651 Southwest Fwy, Ste 250', '500 Maxey Rd, Ste A', '1701 Sunset Blvd', '1701 Sunset Blvd', '8901 FM 1960 West Rd, Ste 204', '1331 W Grand Pkwy N, 350', '2244 West Holcombe Blvd', '2221 Fulton St', '101 W Southmore Ave', '12611 S Gessner Rd', '16001 Park Ten Pl', '25410 Interstate 45 N, Suite 100']

# %%
len(street_name)
# Out:
# 17

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'doctor-card-info-provider-qualities'})

info = []

for title in movies_html:
 info.append(title.text.strip())
print(info)
# Out:
# ['New patient appointments • Also offers video visits • Excellent wait time', 'New patient appointments • Also offers video visits • Highly recommended • Excellent wait time', 'New patient appointments • Highly recommended • Excellent wait time', 'New patient appointments', 'New patient appointments • Excellent wait time', 'New patient appointments • Also offers video visits • Highly recommended • Excellent wait time', 'New patient appointments • Also offers video visits', 'New patient appointments • Also offers video visits • Highly recommended • Excellent wait time', 'New patient appointments • Also offers video visits • Highly recommended • Excellent wait time', 'New patient appointments', 'New patient appointments • Also offers video visits • Excellent wait time', 'New patient appointments • Also offers video visits • Highly recommended • Excellent wait time', 'New patient appointments • Also offers video visits', 'New patient appointments • Also offers video visits', 'New patien
# ...

# %%
len(info)
# Out:
# 17

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({'Doctor Name': doctor_n,
                   'Degree': degree,
                   'Speciality': specialty,
                   'Street-name': street_name,
                   'City': city,
                   'State': state,
                   'Postal-code': postal_code,
                   #'Location': ['1331 W Grand Pkwy N, 350, Katy, TX 77493', '1701 Sunset Blvd, Houston, TX 77005', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', 'Village Medical @ Walgreens - Northshore500 Maxey Rd, Ste A, Houston, TX 77013', 'Houston Methodist Gastroenterology Associates16651 Southwest Fwy, Ste 250, Sugarland, TX 77479', '1701 Sunset Blvd, Houston, TX 77005', '1701 Sunset Blvd, Houston, TX 77005', '1331 W Grand Pkwy N, 350, Katy, TX 77493', '8901 FM 1960 West Rd, Ste 204, Humble, TX 77338', '2244 West Holcombe Blvd, Houston, TX 77030', 'Northside Village2221 Fulton St, Houston, TX 77009', 'Village Medical @ Walgreens - Pasadena Northwest101 W Southmore Ave, Pasadena, TX 77502', '12611 S Gessner Rd, Houston, TX 77071', 'Video visit', 'Memorial Clinical Associates16001 Park Ten Pl, Houston, TX 77084'],
                   'Details': info,
                   'images-URL': b,
                   })

# Create a Pandas Excel writer using XlsxWriter as the engine.
#writer = pd.ExcelWriter('demo.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
#df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
#writer.save()
df
# Out:
#               Doctor Name Degree                 Speciality  \
# 0            Murtaza Arif   , MD         Gastroenterologist
# 1           David S. Wolf   , MD         Gastroenterologist
# 2              Ali Hashmi   , MD         Gastroenterologist
# 3            Avais Chatha   , MD         Gastroenterologist
# 4   Shabbir-Husain Jamali   , MD         Gastroenterologist
# 5           Svetang Desai   , MD         Gastroenterologist
# 6                 Sean Yu   , PA        Physician Assistant
# 7              John Dugan   , MD         Gastroenterologist
# 8   Muhammad Behzad Zafar   , MD         Gastroenterologist
# 9            Ravi Moparty   , MD         Gastroenterologist
# 10           Murtaza Arif   , MD         Gastroenterologist
# 11         Alejandro Mora   , MD                  Internist
# 12      Phuong 'Amy' Pham   , NP  Family Nurse Practitioner
# 13         Bridget Nwaogu   , NP         Nurse Practitioner
# 14         Beatrice Gyebi   , NP         Nurse Practitioner
# ...

# %%
import pandas as pd
import xlsxwriter

# dataframe Name and Age columns
df = pd.DataFrame({'Doctor Name': doctor_n,
                   'Degree': degree,
                   'Speciality': specialty,
                   'Street-name': street_name,
                   'City': city,
                   'State': state,
                   'Postal-code': postal_code,
                   #'Location': ['1331 W Grand Pkwy N, 350, Katy, TX 77493', '1701 Sunset Blvd, Houston, TX 77005', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', '421 School St, Ste. 110, Tomball, TX 77375', 'Village Medical @ Walgreens - Northshore500 Maxey Rd, Ste A, Houston, TX 77013', 'Houston Methodist Gastroenterology Associates16651 Southwest Fwy, Ste 250, Sugarland, TX 77479', '1701 Sunset Blvd, Houston, TX 77005', '1701 Sunset Blvd, Houston, TX 77005', '1331 W Grand Pkwy N, 350, Katy, TX 77493', '8901 FM 1960 West Rd, Ste 204, Humble, TX 77338', '2244 West Holcombe Blvd, Houston, TX 77030', 'Northside Village2221 Fulton St, Houston, TX 77009', 'Village Medical @ Walgreens - Pasadena Northwest101 W Southmore Ave, Pasadena, TX 77502', '12611 S Gessner Rd, Houston, TX 77071', 'Video visit', 'Memorial Clinical Associates16001 Park Ten Pl, Houston, TX 77084'],
                   'Details': info,
                   'images-URL': b,
                   })

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('gastroenterologists-page1.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1', index=False)


# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
#movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-name'})

#dr = []

#for title in movies_html:
 #dr.append(title.text.strip())
#print(dr)

# %%
#

# %%
#page = r.text
#with open(file_name, 'w')as file:
    #file.write(soup.prettify().decode('utf-8'))if type(soup.prettify()) == bytes else file.write(soup.prettify())

# %%
import requests, bs4
from bs4 import BeautifulSoup
def read_file():
    file = open('Customer-reports.txt')
    data = file.read()
    file.close()
    return data
    
soup = BeautifulSoup(read_file(),'lxml')

all_divs = soup.find_all('div',attrs={'data-test': 'doctor-card-info-specialty'})

for div in all_divs:
    product = div.div#.string.text.strip()
    print(product)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
