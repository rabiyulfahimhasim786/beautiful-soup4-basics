# %%
import bs4 from urllib.request 
import FancyURLopener

class MyOpener(FancyURLopener):
    version = 'My new User-Agent' # Set this to a string you want for your user agent

myopener = MyOpener()
sauce = myopener.open('https://finance.yahoo.com/most-active?count=100&guce_referrer=aHR0cHM6Ly9sb2dpbi55YWhvby5jb20v&guce_referrer_sig=AQAAAI9gecImEAchRGLbJWaMQRr0edvgHEKjXhV89uZ46DDqOZKQJn7TsZ4k2hHgl09_vQ3_lYa9k_RWrl-tXRFFIR5zhJ5V0CV59JLQKHGfoDQtb_2cD9RLko43tSWYaqR1DtLibvUkwYkJM5MU71P6bpx7nrUwMbOurSz3MmHf7Qey&offset=0')
soup = bs4.BeautifulSoup(sauce,'lxml')

#table = soupe.table
table = soup.find('table')
table_rows = table.find_all_next('tr')

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_7752/439464989.py", line 1
#     import bs4 from urllib.request
#                ^
# SyntaxError: invalid syntax

# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://finance.yahoo.com/most-active?count=100&guce_referrer=aHR0cHM6Ly9sb2dpbi55YWhvby5jb20v&guce_referrer_sig=AQAAAI9gecImEAchRGLbJWaMQRr0edvgHEKjXhV89uZ46DDqOZKQJn7TsZ4k2hHgl09_vQ3_lYa9k_RWrl-tXRFFIR5zhJ5V0CV59JLQKHGfoDQtb_2cD9RLko43tSWYaqR1DtLibvUkwYkJM5MU71P6bpx7nrUwMbOurSz3MmHf7Qey&offset=0'
#PAGE = 'primaryschools'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
   # (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!DOCTYPE html><html data-color-theme="light" id="atomic" class="NoJs firefox desktop" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark('PageStart');</script><meta charSet="utf-8"/><title>Most Active Stocks Today - Yahoo Finance</title><meta name="keywords" content="Stock Screener, industry, index membership, share data, stock price, market cap, beta, sales, profitability, valuation ratios, analyst estimates, large cap value, bargain growth, preset stock screens"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="458584288257241"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="See the list of the most active stocks today, including share price change and percentage, trading volume, intraday highs and lows, an
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="NoJs firefox desktop" data-color-theme="light" id="atomic" lang="en-US">
#  <head prefix="og: http://ogp.me/ns#">
#   <script>
#    window.performance && window.performance.mark && window.performance.mark('PageStart');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Most Active Stocks Today - Yahoo Finance
#   </title>
#   <meta content="Stock Screener, industry, index membership, share data, stock price, market cap, beta, sales, profitability, valuation ratios, analyst estimates, large cap value, bargain growth, preset stock screens" name="keywords"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <meta content="on" property="twitter:dnt"/>
#   <meta content="458584288257241" property="fb:app_id"/>
#   <meta content="#400090" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
movies_html = soup.find_all('td', attrs={'class': 'Va(m)'})

doctor_n = []

for title in movies_html:
 doctor_n.append(title.text.strip())
print(doctor_n)
# Out:
# ['TLRY', 'Tilray Brands, Inc.', '8.56', '+1.59', '+22.81%', '302.811M', '27.522M', '4.115B', 'N/A', '', 'NIO', 'NIO Inc.', '19.91', '-2.07', '-9.42%', '106.471M', '67.226M', '36.29B', 'N/A', '', 'AMD', 'Advanced Micro Devices, Inc.', '119.67', '-0.86', '-0.71%', '95.201M', '98.662M', '194.746B', '46.56', '', 'SWN', 'Southwestern Energy Company', '6.88', '+0.93', '+15.63%', '79.98M', '26.198M', '7.667B', 'N/A', '', 'AAPL', 'Apple Inc.', '174.72', '+0.65', '+0.37%', '80.546M', '93.172M', '2.851T', '29.05', '', 'AMC', 'AMC Entertainment Holdings, Inc.', '20.24', '+0.01', '+0.05%', '71.166M', '47.582M', '10.39B', 'N/A', '', 'DIDI', 'DiDi Global Inc.', '3.2700', '-0.5300', '-13.95%', '68.727M', '44.418M', '15.772B', 'N/A', '', 'TELL', 'Tellurian Inc.', '5.84', '+0.99', '+20.41%', '67.173M', '16.78M', '3.028B', 'N/A', '', 'F', 'Ford Motor Company', '16.47', '-0.36', '-2.14%', '61.23M', '102.873M', '65.95B', '3.70', '', 'ITUB', 'Itaú Unibanco Holding S.A.', '5.72', '+0.08', '+1.42%', '61.67
# ...

# %%
['TLRY', 'Tilray Brands, Inc.', '8.56', '+1.59', '+22.81%', '302.811M', '27.522M', '4.115B', 'N/A', '', 'NIO', 'NIO Inc.', '19.91', '-2.07', '-9.42%', '106.471M', '67.226M', '36.29B', 'N/A', '', 'AMD', 'Advanced Micro Devices, Inc.', '119.67', '-0.86', '-0.71%', '95.201M', '98.662M', '194.746B', '46.56', '', 'SWN', 'Southwestern Energy Company', '6.88', '+0.93', '+15.63%', '79.98M', '26.198M', '7.667B', 'N/A', '', 'AAPL', 'Apple Inc.', '174.72', '+0.65', '+0.37%', '80.546M', '93.172M', '2.851T', '29.05', '', 'AMC', 'AMC Entertainment Holdings, Inc.', '20.24', '+0.01', '+0.05%', '71.166M', '47.582M', '10.39B', 'N/A', '', 'DIDI', 'DiDi Global Inc.', '3.2700', '-0.5300', '-13.95%', '68.727M', '44.418M', '15.772B', 'N/A', '', 'TELL', 'Tellurian Inc.', '5.84', '+0.99', '+20.41%', '67.173M', '16.78M', '3.028B', 'N/A', '', 'F', 'Ford Motor Company', '16.47', '-0.36', '-2.14%', '61.23M', '102.873M', '65.95B', '3.70', '', 'ITUB', 'Itaú Unibanco Holding S.A.', '5.72', '+0.08', '+1.42%', '61.676M', '46.067M', '55.941B', '10.14', '', 'NVDA', 'NVIDIA Corporation', '276.92', '-4.58', '-1.63%', '57.902M', '52.078M', '690.085B', '71.93', '', 'BBD', 'Banco Bradesco S.A.', '4.6400', '+0.1200', '+2.65%', '43.694M', '39.971M', '49.318B', '9.91', '', 'RIG', 'Transocean Ltd.', '5.03', '+0.60', '+13.54%', '48.541M', '23.822M', '3.297B', 'N/A', '', 'BABA', 'Alibaba Group Holding Limited', '112.99', '-2.16', '-1.88%', '41.557M', '32.086M', '306.855B', '30.16', '', 'SOFI', 'SoFi Technologies, Inc.', '9.01', '-0.46', '-4.86%', '42.216M', '63.188M', '7.205B', 'N/A', '', 'AAL', 'American Airlines Group Inc.', '17.01', '+0.29', '+1.73%', '39.51M', '43.823M', '11.042B', 'N/A', '', 'BAC', 'Bank of America Corporation', '43.73', '+0.66', '+1.53%', '37.865M', '54.462M', '352.676B', '12.25', '', 'CGC', 'Canopy Growth Corporation', '8.69', '+0.79', '+10.00%', '38.446M', '7.564M', '3.425B', 'N/A', '', 'OXY', 'Occidental Petroleum Corporation', '58.71', '+0.96', '+1.66%', '37.01M', '31.588M', '54.839B', '37.35', '', 'FB', 'Meta Platforms, Inc.', '221.82', '+2.25', '+1.02%', '39.987M', '35.708M', '603.781B', '16.11', '', 'EDU', 'New Oriental Education & Technology Group Inc.', '1.2600', '-0.0700', '-5.26%', '20.065M', '27.254M', '2.138B', 'N/A', '', 'INTC', 'Intel Corporation', '51.83', '+0.21', '+0.41%', '33.249M', '39.16M', '211.052B', '10.66', '', 'ET', 'Energy Transfer LP', '10.57', '+0.32', '+3.12%', '30.722M', '21.796M', '32.586B', '5.59', '', 'T', 'AT&T Inc.', '23.84', '+0.51', '+2.19%', '31.757M', '52.907M', '170.767B', '8.63', '', 'UBER', 'Uber Technologies, Inc.', '34.06', '-0.64', '-1.84%', '25.681M', '33.292M', '66.569B', 'N/A', '', 'RYCEY', 'Rolls-Royce Holdings plc', '1.5200', '+0.3100', '+25.62%', '27.548M', '4.597M', '12.835B', '80.00', '', 'VALE', 'Vale S.A.', '19.94', '-0.08', '-0.40%', '27.371M', '36.365M', '96.874B', '3.98', '', 'ABEV', 'Ambev S.A.', '3.0000', '+0.0800', '+2.74%', '26.075M', '22.888M', '47.214B', '18.40', '', 'PDD', 'Pinduoduo Inc.', '44.24', '-0.70', '-1.56%', '25.979M', '14.688M', '55.446B', '51.92', '', 'DNA', 'Ginkgo Bioworks Holdings, Inc.', '3.6600', '-0.0600', '-1.61%', '25.957M', '13.397M', '5.441B', 'N/A', '', 'CCL', 'Carnival Corporation & plc', '18.39', '-0.10', '-0.54%', '25.768M', '39.141M', '21.541B', 'N/A', '', 'NLY', 'Annaly Capital Management, Inc.', '7.27', '+0.06', '+0.83%', '25.722M', '23.967M', '10.617B', '4.55', '', 'ZNGA', 'Zynga Inc.', '9.18', '+0.09', '+0.99%', '25.42M', '36.832M', '10.396B', 'N/A', '', 'KMI', 'Kinder Morgan, Inc.', '19.07', '+0.77', '+4.21%', '23.774M', '17.986M', '43.241B', '24.42', '', 'PLTR', 'Palantir Technologies Inc.', '12.97', '-0.42', '-3.14%', '24.41M', '53.48M', '26.331B', 'N/A', '', 'IQ', 'iQIYI, Inc.', '4.3100', '-0.4600', '-9.64%', '22.796M', '17.981M', '3.712B', 'N/A', '', 'SNAP', 'Snap Inc.', '35.40', '-1.65', '-4.45%', '22.163M', '35.043M', '57.5B', 'N/A', '', 'CLF', 'Cleveland-Cliffs Inc.', '33.00', '+0.33', '+1.01%', '22.539M', '23.621M', '17.339B', '6.16', '', 'MSFT', 'Microsoft Corporation', '303.68', '-0.42', '-0.14%', '22.566M', '37.172M', '2.277T', '32.34', '', 'MU', 'Micron Technology, Inc.', '78.10', '-0.11', '-0.14%', '22.491M', '22.095M', '87.455B', '12.09', '', 'XOM', 'Exxon Mobil Corporation', '85.20', '+1.82', '+2.18%', '21.371M', '32.634M', '360.702B', '15.81', '', 'JOBY', 'Joby Aviation, Inc.', '5.98', '+0.65', '+12.20%', '22.161M', '6.118M', '3.613B', 'N/A', '', 'EQT', 'EQT Corporation', '34.33', '+3.59', '+11.68%', '21.172M', '9.127M', '12.909B', 'N/A', '', 'GGB', 'Gerdau S.A.', '6.41', '+0.05', '+0.79%', '21.24M', '10.563M', '10.933B', '3.42', '', 'C', 'Citigroup Inc.', '56.74', '+0.32', '+0.57%', '20.185M', '27.304M', '112.396B', '5.59', '', 'RBLX', 'Roblox Corporation', '47.07', '-3.72', '-7.32%', '20.981M', '24.393M', '27.666B', 'N/A', '', 'TWTR', 'Twitter, Inc.', '38.60', '-0.22', '-0.57%', '20.601M', '18.661M', '30.905B', 'N/A', '', 'TSLA', 'Tesla, Inc.', '1,010.64', '-3.28', '-0.32%', '20.677M', '26.594M', '1.045T', '206.21', '', 'LU', 'Lufax Holding Ltd', '6.02', '-0.53', '-8.09%', '20.155M', '10.673M', '15.276B', '5.74', '', 'PBR', 'Petróleo Brasileiro S.A. - Petrobras', '14.69', '+0.23', '+1.59%', '19.891M', '34.308M', '95.812B', '4.34', '', 'NCLH', 'Norwegian Cruise Line Holdings Ltd.', '19.86', '+0.11', '+0.56%', '19.468M', '23.028M', '8.283B', 'N/A', '', 'WFC', 'Wells Fargo & Company', '52.56', '+1.23', '+2.40%', '18.595M', '32.168M', '200.493B', '10.62', '', 'UMC', 'United Microelectronics Corporation', '9.44', '+0.04', '+0.43%', '19.009M', '10.157M', '23.368B', '12.03', '', 'MRO', 'Marathon Oil Corporation', '26.04', '+0.51', '+2.00%', '19.59M', '21.738M', '19.029B', '21.70', '', 'TME', 'Tencent Music Entertainment Group', '4.9600', '-0.2600', '-4.98%', '18.87M', '17.825M', '8.395B', '17.59', '', 'FCEL', 'FuelCell Energy, Inc.', '6.22', '-0.40', '-6.04%', '18.878M', '25.218M', '2.281B', 'N/A', '', 'VZ', 'Verizon Communications Inc.', '51.28', '+0.28', '+0.55%', '18.587M', '23.697M', '215.264B', '9.64', '', 'NKLA', 'Nikola Corporation', '10.11', '+0.45', '+4.66%', '18.627M', '17.045M', '4.22B', 'N/A', '', 'NOK', 'Nokia Oyj', '5.37', '+0.03', '+0.56%', '18.516M', '28.513M', '30.504B', '16.94', '', 'CVE', 'Cenovus Energy Inc.', '16.81', '+0.74', '+4.60%', '18.161M', '13.112M', '33.541B', '78.19', '', 'CSCO', 'Cisco Systems, Inc.', '54.97', '+0.47', '+0.86%', '18.092M', '21.933M', '228.355B', '19.63', '', 'BEKE', 'KE Holdings Inc.', '12.13', '-1.06', '-8.04%', '14.242M', '16.226M', '14.52B', 'N/A', '', 'CPNG', 'Coupang, Inc.', '17.70', '-1.22', '-6.45%', '17.495M', '11.991M', '31.075B', 'N/A', '', 'PFE', 'Pfizer Inc.', '52.78', '+0.19', '+0.36%', '15.84M', '34.272M', '298.089B', '13.69', '', 'LCID', 'Lucid Group, Inc.', '25.16', '-1.09', '-4.15%', '17.277M', '33.905M', '41.596B', 'N/A', '', 'GOLD', 'Barrick Gold Corporation', '24.54', '+0.04', '+0.16%', '16.975M', '22.933M', '43.665B', '21.58', '', 'BP', 'BP p.l.c.', '31.05', '+0.31', '+1.01%', '16.859M', '17.267M', '101.215B', '13.87', '', 'DKNG', 'DraftKings Inc.', '18.20', '-0.85', '-4.46%', '16.684M', '27.53M', '7.438B', 'N/A', '', 'ERIC', 'Telefonaktiebolaget LM Ericsson (publ)', '9.27', '+0.06', '+0.65%', '16.1M', '10.844M', '30.87B', 'N/A', '', 'JD', 'JD.com, Inc.', '59.92', '-1.60', '-2.60%', '16.014M', '14.998M', '93.835B', 'N/A', '', 'VTRS', 'Viatris Inc.', '11.19', '+0.24', '+2.19%', '15.723M', '13.221M', '13.535B', 'N/A', '', 'OPEN', 'Opendoor Technologies Inc.', '8.65', '-0.38', '-4.21%', '15.631M', '16.354M', '5.453B', 'N/A', '', 'GRAB', 'Grab Holdings Limited', '3.3000', '-0.3300', '-9.09%', '15.601M', '25.724M', '12.346B', 'N/A', '', 'CTRA', 'Coterra Energy Inc.', '28.91', '+1.88', '+6.96%', '15.023M', '10.01M', '23.445B', '12.62', '', 'CMCSA', 'Comcast Corporation', '47.13', '+0.33', '+0.71%', '15.015M', '22.436M', '213.651B', '15.50', '', 'SIRI', 'Sirius XM Holdings Inc.', '6.56', '+0.06', '+0.92%', '14.708M', '21.694M', '25.898B', '20.56', '', 'BILI', 'Bilibili Inc.', '27.53', '-2.78', '-9.17%', '14.359M', '9.056M', '10.542B', 'N/A', '', 'CDEV', 'Centennial Resource Development, Inc.', '8.65', '+0.42', '+5.10%', '14.347M', '9.267M', '2.465B', '18.76', '', 'IBN', 'ICICI Bank Limited', '18.19', '-0.07', '-0.38%', '14.073M', '11.323M', '63.668B', '22.13', '', 'PLUG', 'Plug Power Inc.', '27.95', '-0.51', '-1.79%', '14.138M', '21.035M', '16.155B', 'N/A', '', 'STNE', 'StoneCo Ltd.', '12.30', '-2.05', '-14.29%', '14.028M', '8.369M', '3.537B', 'N/A', '', 'PLAN', 'Anaplan, Inc.', '64.94', '+0.16', '+0.25%', '13.59M', '5.48M', '9.755B', 'N/A', '', 'MQ', 'Marqeta, Inc.', '11.02', '-1.08', '-8.93%', '13.741M', '8.375M', '5.982B', 'N/A', '', 'XPEV', 'XPeng Inc.', '27.05', '-2.21', '-7.55%', '13.905M', '12.429M', '23.166B', 'N/A', '', 'PBR-A', 'Petróleo Brasileiro S.A. - Petrobras', '13.54', '+0.12', '+0.89%', '13.376M', '13.794M', '75.851B', '4.00', '', 'X', 'United States Steel Corporation', '38.45', '+0.25', '+0.65%', '14.17M', '20.066M', '10.033B', '2.58', '', 'SQ', 'Block, Inc.', '130.33', '-4.73', '-3.50%', '13.131M', '20.352M', '75.599B', '394.94', '', 'HPQ', 'HP Inc.', '39.84', '+1.31', '+3.40%', '12.693M', '12.225M', '41.966B', '7.16', '', 'UPST', 'Upstart Holdings, Inc.', '103.77', '-11.68', '-10.12%', '13.358M', '10.42M', '8.723B', '72.57', '', 'RLX', 'RLX Technology Inc.', '1.9600', '-0.0900', '-4.39%', '13.421M', '14.665M', '3.079B', '8.71', '', 'GME', 'GameStop Corp.', '151.95', '+9.56', '+6.71%', '13.335M', '3.86M', '11.6B', 'N/A', '', 'UAL', 'United Airlines Holdings, Inc.', '43.18', '+0.40', '+0.94%', '12.835M', '14.623M', '14.017B', 'N/A', '', 'KOS', 'Kosmos Energy Ltd.', '7.02', '+0.39', '+5.88%', '12.727M', '11.499M', '3.196B', 'N/A', '', 'BBBY', 'Bed Bath & Beyond Inc.', '22.59', '+0.49', '+2.22%', '12.62M', '8.671M', '2.176B', 'N/A', '', 'ING', 'ING Groep N.V.', '10.37', '-0.02', '-0.19%', '12.54M', '6.951M', '39.029B', '7.67', '', 'TEVA', 'Teva Pharmaceutical Industries Limited', '8.62', '+0.45', '+5.51%', '12.332M', '8.893M', '9.53B', '22.80', '', 'PYPL', 'PayPal Holdings, Inc.', '113.76', '-2.29', '-1.97%', '12.378M', '21.771M', '132.53B', '32.32', '', 'KGC', 'Kinross Gold Corporation', '5.73', '+0.07', '+1.24%', '12.072M', '20.827M', '7.412B', '33.71', '', 'KO', 'The Coca-Cola Company', '61.53', '+0.55', '+0.90%', '11.244M', '19.375M', '266.761B', '27.35', '', 'SLB', 'Schlumberger Limited', '43.68', '+1.04', '+2.44%', '12.076M', '17.235M', '61.726B', '33.09', '']
