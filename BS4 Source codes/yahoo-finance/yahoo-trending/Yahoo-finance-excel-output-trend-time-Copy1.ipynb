# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://finance.yahoo.com/trending-tickers'
#PAGE = 'primaryschools'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
   # (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!DOCTYPE html><html data-color-theme="light" id="atomic" class="NoJs firefox desktop" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark('PageStart');</script><meta charSet="utf-8"/><title>Trending Stocks Today - Yahoo Finance</title><meta name="keywords" content="trending tickers, popular tickers, trending, popular, now, most popular, people"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="458584288257241"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="See the list of trending stocks today, including share price change and percentage, trading volume, intraday highs and lows, and day charts."/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><meta name="msvalidate.01" content="A9862C0E6E1BE95B
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="NoJs firefox desktop" data-color-theme="light" id="atomic" lang="en-US">
#  <head prefix="og: http://ogp.me/ns#">
#   <script>
#    window.performance && window.performance.mark && window.performance.mark('PageStart');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Trending Stocks Today - Yahoo Finance
#   </title>
#   <meta content="trending tickers, popular tickers, trending, popular, now, most popular, people" name="keywords"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <meta content="on" property="twitter:dnt"/>
#   <meta content="458584288257241" property="fb:app_id"/>
#   <meta content="#400090" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="See the list of trending stocks today, including share price change and percentage, trading volume, intraday highs and lows, and day charts." lang="en-US" name="description"/>
# ...

# %%
movies_html = soup.find_all('td', attrs={'aria-label': 'Name'})

doctor_n = []

for title in movies_html:
 doctor_n.append(title.text.strip())
print(doctor_n)
# Out:
# ['Robinhood Markets, Inc.', 'Micron Technology, Inc.', 'Lululemon Athletica Inc.', 'Rivian Automotive, Inc.', 'Chewy, Inc.', 'RH', 'MicroVision, Inc.', 'IGM Biosciences, Inc.', 'Dutch Bros Inc.', 'YETI Holdings, Inc.', 'Nielsen Holdings plc', 'Virgin Galactic Holdings, Inc.', 'Tata Consumer Products Limited', 'SoFi Technologies, Inc.', 'Matterport, Inc.', 'Happiest Minds Technologies Limited', 'Vinco Ventures, Inc.', 'Peloton Interactive, Inc.', 'Lucid Group, Inc.', 'Nikkei 225', 'Tata Coffee Limited', 'Geron Corporation', 'China SXT Pharmaceuticals, Inc.', 'Microvast Holdings, Inc.', 'Nasdaq Futures', 'Cargojet Inc.', 'Hero MotoCorp Limited', 'Tricon Residential Inc.', 'CVS Health Corporation', 'Zoom Video Communications, Inc.']

# %%
len(doctor_n)
# Out:
# 30

# %%
price_html = soup.find_all('td', attrs={'aria-label': 'Last Price'})

price_n = []

for title in price_html:
 price_n.append(title.text.strip())
print(price_n)
# Out:
# ['15.91', '82.05', '343.97', '53.88', '51.00', '385.69', '5.55', '29.49', '62.77', '61.30', '26.72', '11.01', '774.90', '10.14', '9.36', '1,101.25', '3.3800', '30.89', '27.36', '27,824.01', '217.95', '1.2800', '0.2937', '7.42', '15,214.00', '185.03', '2,263.60', '16.43', '104.68', '126.26']

# %%
len(price_n)
# Out:
# 30

# %%
market_time_html = soup.find_all('td', attrs={'aria-label': 'Market Time'})

market_time_n = []

for title in market_time_html:
 market_time_n.append(title.text.strip())
print(market_time_n)
# Out:
# ['4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '11:14AM IST', '4:00PM EDT', '4:00PM EDT', '11:14AM IST', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '2:24PM JST', '11:14AM IST', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT', '1:34AM EDT', '4:00PM EDT', '11:14AM IST', '4:00PM EDT', '4:00PM EDT', '4:00PM EDT']

# %%
len(market_time_n)
# Out:
# 30

# %%
change_html = soup.find_all('td', attrs={'aria-label': 'Change'})

change_n = []

for title in change_html:
 change_n.append(title.text.strip())
print(change_n)
# Out:
# ['+3.10', '+2.19', '+12.19', '+7.90', '+2.20', '+18.19', '+1.37', '+14.50', '+6.92', '+4.21', '+4.51', '+1.25', '+31.70', '+0.89', '+1.40', '+41.05', '+0.4100', '+2.82', '+1.98', '-428.41', '+21.70', '+0.0700', '+0.0917', '+0.25', '-23.75', '+21.54', '+52.95', '+0.18', '-3.36', '+8.81']

# %%
len(change_n)
# Out:
# 30

# %%
change_percentage_html = soup.find_all('td', attrs={'aria-label': '% Change'})

change_percentage_n = []

for title in change_percentage_html:
 change_percentage_n.append(title.text.strip())
print(change_percentage_n)
# Out:
# ['+24.20%', '+2.74%', '+3.67%', '+17.18%', '+4.51%', '+4.95%', '+32.78%', '+96.73%', '+12.39%', '+7.37%', '+20.31%', '+12.81%', '+4.27%', '+9.62%', '+17.59%', '+3.87%', '+13.80%', '+10.05%', '+7.80%', '-1.52%', '+11.06%', '+5.79%', '+45.40%', '+3.49%', '-0.16%', '+13.18%', '+2.40%', '+1.11%', '-3.11%', '+7.50%']

# %%
len(change_percentage_n)
# Out:
# 30

# %%
volume_html = soup.find_all('td', attrs={'aria-label': 'Volume'})

volume_n = []

for title in volume_html:
 volume_n.append(title.text.strip())
print(volume_n)
# Out:
# ['101.119M', '40.363M', '3.157M', '26.254M', '7.447M', '1.58M', '27.879M', '42.05M', '4.857M', '1.203M', '114.526M', '30.483M', '4.828M', '72.805M', '15.818M', '328,073', '44.482M', '14.279M', '33.667M', '0', '11.201M', '3.28M', '215.513M', '1.385M', '26,143', '187,833', '1.998M', '809,701', '8.347M', '4.757M']

# %%
len(volume_n)
# Out:
# 30

# %%
#avg_volume_html = soup.find_all('td', attrs={'aria-label': 'Market Cap'})

#avg_volume_n = []

#for title in avg_volume_html:
 #avg_volume_n.append(title.text.strip())
#print(avg_volume_n)

# %%
#len(mkt_cap_n)

# %%
market_cap_html = soup.find_all('td', attrs={'aria-label': 'Market Cap'})

market_cap_n = []

for title in market_cap_html:
 market_cap_n.append(title.text.strip())
print(market_cap_n)
# Out:
# ['13.296B', '91.878B', '44.002B', '47.598B', '21.317B', '8.28B', '913.697M', '957.296M', '10.276B', '5.336B', '9.605B', '2.934B', '714.148B', '8.108B', '2.628B', '161.734B', '632.239M', '10.243B', '45.233B', 'N/A', '40.717B', '414.377M', '8.549M', '2.23B', 'N/A', '3.206B', '452.294B', '4.472B', '137.394B', '37.767B']

# %%
len(market_cap_n)
# Out:
# 30

# %%
#ratio_html = soup.find_all('td', attrs={'aria-label': 'PE Ratio (TTM)'})

#ratio_n = []

#for title in ratio_html:
 #ratio_n.append(title.text.strip())
#print(ratio_n)

# %%
#len(ratio_n)

# %%
symbol_html = soup.find_all('a', attrs={'class': 'Fw(600) C($linkColor)'})

symbol_n = []

for title in symbol_html:
 symbol_n.append(title.text.strip())
print(symbol_n)
# Out:
# ['HOOD', 'MU', 'LULU', 'RIVN', 'CHWY', 'RH', 'MVIS', 'IGMS', 'BROS', 'YETI', 'NLSN', 'SPCE', 'TATACONSUM.NS', 'SOFI', 'MTTR', 'HAPPSTMNDS.NS', 'BBIG', 'PTON', 'LCID', '^N225', 'TATACOFFEE.NS', 'GERN', 'SXTC', 'MVST', 'NQ=F', 'CJT.TO', 'HEROMOTOCO.NS', 'TCN', 'CVS', 'ZM']

# %%
len(symbol_n)
# Out:
# 30

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({'Brand Symbol': symbol_n,
                   'Brand Titles': doctor_n,
                   'price': price_n,
                   'Market Time': market_time_n,
                   'Change': change_n,
                   'Change Precentage': change_percentage_n,
                   'Volume': volume_n,
                   #'Average Volume': avg_volume_n,
                   'Market Cap': market_cap_n,})
                   #'Ratio': ratio_n,})
# Create a Pandas Excel writer using XlsxWriter as the engine.
#writer = pd.ExcelWriter('linkedindata.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
#df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
#writer.save()

# %%
df
# Out:
#      Brand Symbol                         Brand Titles      price  \
# 0            HOOD              Robinhood Markets, Inc.      15.91
# 1              MU              Micron Technology, Inc.      82.05
# 2            LULU             Lululemon Athletica Inc.     343.97
# 3            RIVN              Rivian Automotive, Inc.      53.88
# 4            CHWY                          Chewy, Inc.      51.00
# 5              RH                                   RH     385.69
# 6            MVIS                    MicroVision, Inc.       5.55
# 7            IGMS                IGM Biosciences, Inc.      29.49
# 8            BROS                      Dutch Bros Inc.      62.77
# 9            YETI                  YETI Holdings, Inc.      61.30
# 10           NLSN                 Nielsen Holdings plc      26.72
# 11           SPCE       Virgin Galactic Holdings, Inc.      11.01
# 12  TATACONSUM.NS       Tata Consumer Products Limited     774.90
# ...

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({'Brand Symbol': symbol_n,
                   'Brand Titles': doctor_n,
                   'price': price_n,
                   'Market Time': market_time_n,
                   'Change': change_n,
                   'Change Precentage': change_percentage_n,
                   'Volume': volume_n,
                   #'Average Volume': avg_volume_n,
                   'Market Cap': market_cap_n,})
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('yahoo-finance-trending-01-.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
