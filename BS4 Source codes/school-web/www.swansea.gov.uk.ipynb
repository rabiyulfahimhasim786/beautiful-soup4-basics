# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://www.swansea.gov.uk/'
PAGE = 'primaryschools'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!DOCTYPE html>
# <html xml:lang="en-gb" lang="en-gb"><head>
#
#
# 	<title>Primary schools - Swansea</title>
# 		<base href="https://www.swansea.gov.uk/" />
#
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
# 		<meta name="description" content="Full list of primary schools in Swansea." />
# 		<link rel="shortcut icon" href="/image/1384/Swansea-Citizen-Logo---Favicon/favicon.png?m=1620714938910" />
# 		<link rel="apple-touch-icon" sizes="32x32" href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconsmall.png?m=1620714938910" />
# 		<link rel="apple-touch-icon" sizes="76x76" href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconmedium.png?m=1620714938910" />
# 		<link rel="apple-touch-icon" sizes="152x152" href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconlarge.png?m=1620714938910" />
# 		<script>
# 			window["ga-disable-UA-613032-1"] = true;
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-gb" xml:lang="en-gb">
#  <head>
#   <title>
#    Primary schools - Swansea
#   </title>
#   <base href="https://www.swansea.gov.uk/"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Full list of primary schools in Swansea." name="description"/>
#   <link href="/image/1384/Swansea-Citizen-Logo---Favicon/favicon.png?m=1620714938910" rel="shortcut icon"/>
#   <link href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconsmall.png?m=1620714938910" rel="apple-touch-icon" sizes="32x32"/>
#   <link href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconmedium.png?m=1620714938910" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/image/1384/Swansea-Citizen-Logo---Favicon/appletouchiconlarge.png?m=1620714938910" rel="apple-touch-icon" sizes="152x152"/>
#   <script>
#    window["ga-disable-UA-613032-1"] = true;
#   </script>
# ...

# %%
for item in soup.find_all('img'):
	print(item['src'])
# Out:
# /image/1382/Swansea-Citizen-Logo---Colour/logo.png?m=1640170879837
# /themes/dynamic/images/facebook.png?m=1638972800000
# /themes/dynamic/images/twitter.png?m=1638972800000
# /themes/dynamic/images/email.png?m=1638972800000
# /themes/dynamic/images/print.png?m=1638972800000
# /image/1310/Swansea-Citizen-Icon---Facebook/footerIcon.png?m=1620715110853
# /image/1311/Swansea-Citizen-Icon---Twitter/footerIcon.png?m=1620715987443
# /image/1386/Swansea-Citizen-Icon---Youtube/footerIcon.png?m=1620715225487
# /image/1385/Swansea-Citizen-Icon---Instagram/footerIcon.png?m=1620715176277

# %%
for item in soup.find_all('img'):
    images = []
    items = (item['src'])
    images = 'https:'+items
    print(images)
# Out:
# https:/image/1382/Swansea-Citizen-Logo---Colour/logo.png?m=1640170879837
# https:/themes/dynamic/images/facebook.png?m=1638972800000
# https:/themes/dynamic/images/twitter.png?m=1638972800000
# https:/themes/dynamic/images/email.png?m=1638972800000
# https:/themes/dynamic/images/print.png?m=1638972800000
# https:/image/1310/Swansea-Citizen-Icon---Facebook/footerIcon.png?m=1620715110853
# https:/image/1311/Swansea-Citizen-Icon---Twitter/footerIcon.png?m=1620715987443
# https:/image/1386/Swansea-Citizen-Icon---Youtube/footerIcon.png?m=1620715225487
# https:/image/1385/Swansea-Citizen-Icon---Instagram/footerIcon.png?m=1620715176277

# %%
images = ['https:'+item['src'] for item in soup.find_all('img')]
print(images)
# Out:
# ['https:/image/1382/Swansea-Citizen-Logo---Colour/logo.png?m=1640170879837', 'https:/themes/dynamic/images/facebook.png?m=1638972800000', 'https:/themes/dynamic/images/twitter.png?m=1638972800000', 'https:/themes/dynamic/images/email.png?m=1638972800000', 'https:/themes/dynamic/images/print.png?m=1638972800000', 'https:/image/1310/Swansea-Citizen-Icon---Facebook/footerIcon.png?m=1620715110853', 'https:/image/1311/Swansea-Citizen-Icon---Twitter/footerIcon.png?m=1620715987443', 'https:/image/1386/Swansea-Citizen-Icon---Youtube/footerIcon.png?m=1620715225487', 'https:/image/1385/Swansea-Citizen-Icon---Instagram/footerIcon.png?m=1620715176277']

# %%
d = images
len(d)
# Out:
# 9

# %%
#

# %%
#

# %%
movies_html = soup.find_all('dd', attrs={'class': 'contact__value--name'})

doctor_n = []

for title in movies_html:
 doctor_n.append(title.text.strip())
print(doctor_n)
# Out:
# ['Birchgrove Primary School', 'Bishopston Primary School', 'Blaenymaes Primary School', 'Brynhyfryd Primary School', 'Brynmill Primary School', 'Burlais Primary School', 'Cadle Primary School', 'Casllwchwr Primary School', 'Cila Primary School', 'Clase Primary School']

# %%
len(doctor_n)
# Out:
# 10

# %%
movies_html = soup.find_all('dd', attrs={'class': 'contact__value--job'})

name = []

for title in movies_html:
 name.append(title.text.strip())
print(name)
# Out:
# ["Headteacher - Mr Matthew O'Brien", 'Acting Headteacher - Mr John Owen', 'Headteacher - Mr Mark Dennis', 'Headteacher - Miss Kathryn Richards', 'Headteacher - Miss Jo Simons', 'Headteacher - Mr Mark Thompson', 'Headteacher - Mr Jamie M Richards', 'Headteacher - Mr Peter Owen', 'Headteacher - Mr Ray Squires', 'Headteacher - Mrs Sharon Hope']

# %%
len(name)
# Out:
# 10

# %%
movies_html = soup.find_all('a', attrs={'class': 'contact__link--email'})

email = []

for title in movies_html:
 email.append(title.text.strip())
print(email)
# Out:
# ['BirchgrovePrimarySchool@birchgrove-pri.swansea.sch.uk', 'BishopstonPrimarySchool@bishopston-pri.swansea.sch.uk', 'BlaenymaesPrimarySchool@blaenymaes.swansea.sch.uk', 'BrynhyfrydPrimarySchool@brynhyfrydpri.swansea.sch.uk', 'BrynmillPrimarySchool@brynmill.swansea.sch.uk', 'BurlaisPrimarySchool@burlaisprimary.swansea.sch.uk', 'CadlePrimarySchool@cadle.swansea.sch.uk', 'CasllwchwrPrimarySchool@casllwchwr.swansea.sch.uk', 'CilaPrimarySchool@cila.swansea.sch.uk', 'ClasePrimarySchool@clase.swansea.sch.uk']

# %%
len(email)
# Out:
# 10

# %%
movies_html = soup.find_all('dd', attrs={'class': 'contact__value--tel'})

telephone = []

for title in movies_html:
 telephone.append(title.text.strip())
print(telephone)
# Out:
# ['01792 814814', '01792 232754', '01792 583366', '01792 483870', '01792 463019', '01792 652350', '01792 584498', '01792 892420', '01792 202775', '01792 781747']

# %%
len(telephone)
# Out:
# 10

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({'Schools': doctor_n,
                   'Teachers name': name,
                   'E-mail': email,
                   'Telephone': telephone,
                   })

# Create a Pandas Excel writer using XlsxWriter as the engine.
#writer = pd.ExcelWriter('demo.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
#df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
#writer.save()
df
# Out:
#                      Schools                        Teachers name  \
# 0  Birchgrove Primary School     Headteacher - Mr Matthew O'Brien
# 1  Bishopston Primary School    Acting Headteacher - Mr John Owen
# 2  Blaenymaes Primary School         Headteacher - Mr Mark Dennis
# 3  Brynhyfryd Primary School  Headteacher - Miss Kathryn Richards
# 4    Brynmill Primary School         Headteacher - Miss Jo Simons
# 5     Burlais Primary School       Headteacher - Mr Mark Thompson
# 6       Cadle Primary School    Headteacher - Mr Jamie M Richards
# 7  Casllwchwr Primary School          Headteacher - Mr Peter Owen
# 8        Cila Primary School         Headteacher - Mr Ray Squires
# 9       Clase Primary School        Headteacher - Mrs Sharon Hope
#
#                                               E-mail     Telephone
# 0  BirchgrovePrimarySchool@birchgrove-pri.swansea...  01792 814814
# 1  BishopstonPrimarySchool@bishopston-pri.swansea...  01792 232754
# ...

# %%
import pandas as pd
import xlsxwriter


# dataframe Name and Age columns
df = pd.DataFrame({'School Name': doctor_n,
                   'Teachers name': name,
                   'E-mail': email,
                   'Telephone': telephone,
                   })

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('primary-schoolnames-.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1', index=False)


# Close the Pandas Excel writer and output the Excel file.
writer.save()
