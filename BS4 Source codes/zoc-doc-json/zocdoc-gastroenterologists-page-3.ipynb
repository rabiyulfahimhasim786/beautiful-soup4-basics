# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://www.zocdoc.com'
PAGE = 'gastroenterologists/3'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()
    # process content from here
print(r.text)
# Out:
# <!doctype html>
#     <html lang="en">
#         <head>
#             <meta name="msapplication-TileImage" content="/images/rebrand/favicon/favicon_large.png" />
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />
# <meta name="format-detection" content="telephone=no" />
#             <link rel="shortcut icon" type="image/x-icon" href="https://www.zocdoc.com/favicon.ico" sizes="32x32" />
# <link rel="dns-prefetch" href="//api.zocdoc.com" />
# <link rel="dns-prefetch" href="//www.zocdoc.com" />
# <link rel="preconnect" href="https://api.zocdoc.com" />
# <link rel="preconnect" href="https://www.zocdoc.com" />
# <link rel="dns-prefetch" href="//dd.zocdoc.com" />
# <link rel="preconnect" href="https://dd.zocdoc.com" />
# <link rel="dns-prefetch" href="//js.captcha-display.com" />
# <link rel="preconnect" href="https://js.captcha-display.com" />
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="/images/rebrand/favicon/favicon_large.png" name="msapplication-TileImage"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.zocdoc.com/favicon.ico" rel="shortcut icon" sizes="32x32" type="image/x-icon"/>
#   <link href="//api.zocdoc.com" rel="dns-prefetch"/>
#   <link href="//www.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://api.zocdoc.com" rel="preconnect"/>
#   <link href="https://www.zocdoc.com" rel="preconnect"/>
#   <link href="//dd.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://dd.zocdoc.com" rel="preconnect"/>
#   <link href="//js.captcha-display.com" rel="dns-prefetch"/>
#   <link href="https://js.captcha-display.com" rel="preconnect"/>
#   <link href="//d1uhlocgth3qyq.cloudfront.net" rel="dns-prefetch"/>
# ...

# %%
users = soup.find_all('div', {'data-test': 'search-content'})

# %%
 for use in users:
    doctor = use.find('span', attrs={'data-test': 'doctor-card-info-name-full'}).text#.replace('\n', '')
    specialty = use.find('div', attrs={'data-test': 'doctor-card-info-specialty'}).text
    location = use.find('div', attrs={'data-test': 'doctor-card-info-location'}).text
   #specialty = list.find('div', class_="sc-192nc1l-0 buuGUI overflown")#.text.replace('\n', '')
   #price = list.find('div', class_="listing-search-item__price").text.replace('\n', '')
   #area = list.find('div', class_="listing-search-item__features").text.replace('\n', '')
    info = [doctor, specialty, location] #price, area]
    print(info)
# Out:
# ['Neal Joseph', 'Gastroenterologist', '123 William Street, 15th Floor, New York, NY 10038']

# %%
movies_html = soup.find_all('span', attrs={'data-test': 'doctor-card-info-name-full'})

doctor = []

for title in movies_html:
 doctor.append(title.text.strip())
print(doctor)
# Out:
# ['Laura Frado', 'Neal Joseph', 'Valerie Antoine-Gustave', 'Deborah Yvette L. Chua', 'Jay Desai', 'Jason Rubinov', 'Jessica Kimmel', 'Mejdi Ahmad', 'James Salik', 'Inessa Khaykis', 'Neal Joseph', 'Inessa Khaykis', 'Jay Desai', 'Jay Desai', 'James Palma', 'Jay Desai', 'Jay Desai', 'Max Pitman', 'Max Pitman', 'Dov Grant', 'Jeffrey Crespin', 'Jessica Kimmel', 'Jessica Kimmel', 'Markos Koutsos', 'Edward Brettholz', 'James Salik', 'Timothy Wong', 'Timothy Johnson', 'Deborah Yvette L. Chua', 'Laura Frado', 'Laura Frado', 'Mejdi Ahmad', 'Michael Dann', 'Prem Chattoo', 'Valerie Antoine-Gustave', 'Valerie Antoine-Gustave', 'Jason Rubinov', 'Neville Bamji', 'Jason Rubinov', 'Michael Eng']

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'doctor-card-info-specialty'})

specialty = []

for title in movies_html:
 specialty.append(title.text.strip())
print(specialty)
# Out:
# ['Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist']

# %%
len(specialty)
# Out:
# 30

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'doctor-card-info-location'})

location = []

for title in movies_html:
 location.append(title.text.strip())
print(location)
# Out:
# ['123 William Street, 15th Floor, New York, NY 10038', '36 E 31st St, Suite 701, New York, NY 10016', '311 East 79th Street, Suite 2A, New York, NY 10075', '57 West 57th Street, Suite 1107, New York, NY 10019', '300 Cadman Plaza West, 18th floor, Brooklyn, NY 11201', '50 Court St, Ste 1102, Brooklyn, NY 11201', '121 East 60th Street, Suite 9B, New York, NY 10022', '252 East 61st St, 1DN, New York, NY 10065', '50 Court St, Ste 1102, Brooklyn, NY 11201', '205 W 54th St, Suite 1B, New York, NY 10019', '36 E 31st St, Suite 701, New York, NY 10016', '77 Bowery, 7th Floor, New York, NY 10002', '128 Mott Street, Suite 202, New York, NY 10013', '535 5th Ave, 611, New York, NY 10017', '300 Cadman Plaza West, 18th floor, Brooklyn, NY 11201', 'Medical Offices of Manhattan - Midtown211 E 51st St, New York, NY 10022', '122 Fulton St., 6th Floor, New York, NY 10038', '123 William Street, 15th Floor, New York, NY 10038', '115 East 23rd Street, 10th Floor, New York, NY 10010']

# %%
len(location)
# Out:
# 19

# %%
movies_html = soup.find_all('div', attrs={'data-test': 'collapsible-block'})

details = []

for title in movies_html:
 details.append(title.text.strip())
print(details)
# Out:
# ['"Thank you for seeing me so quickly! It was really appreciated."... read more... read less', 'Neal Joseph, M.D. is board certified in gastroenterology and internal medicine. Following in the footsteps of his father, a gastroenterologist and his mother, a nutritionist, Dr. Joseph got a head start to learning about digestive disorders, and this early exposure inspired his passion to become a physician. He graduated summa cum laude with a B.A. in Biology from the prestigious accelerated BA/M.D. 7-year Combined Degree Program at the George Washington University. After earning his M.D., Dr. Joseph completed his internal medicine residency at University of Miami Jackson Memorial Hospital, and subsequently pursued specialty training in gastroenterology at Lenox Hill Hospital, NY. Dr. Joseph’s practice encompasses the full breadth of gastroenterology, including colon cancer screening, colonoscopy, upper endoscopy, polyp removal, acid reflux, abdominal pain, inflammatory bowel disease, and 
# ...

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({'Doctor Name': ['Laura Frado', 'Neal Joseph', 'Valerie Antoine-Gustave', 'Deborah Yvette L. Chua', 'Jay Desai', 'Jason Rubinov', 'Jessica Kimmel', 'Mejdi Ahmad', 'James Salik', 'Inessa Khaykis', 'Neal Joseph', 'Inessa Khaykis', 'Jay Desai', 'Jay Desai', 'James Palma', 'Jay Desai', 'Jay Desai', 'Max Pitman', 'Max Pitman', 'Dov Grant', 'Jeffrey Crespin', 'Jessica Kimmel', 'Jessica Kimmel', 'Markos Koutsos', 'Edward Brettholz', 'James Salik', 'Timothy Wong', 'Timothy Johnson', 'Deborah Yvette L. Chua', 'Laura Frado', 'Laura Frado', 'Mejdi Ahmad', 'Michael Dann', 'Prem Chattoo', 'Valerie Antoine-Gustave', 'Valerie Antoine-Gustave', 'Jason Rubinov', 'Neville Bamji', 'Jason Rubinov', 'Michael Eng'],
                   #'Company Name': ['Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist', 'Gastroenterologist'],
                   'Location': ['123 William Street, 15th Floor, New York, NY 10038', '36 E 31st St, Suite 701, New York, NY 10016', '311 East 79th Street, Suite 2A, New York, NY 10075', '57 West 57th Street, Suite 1107, New York, NY 10019', '300 Cadman Plaza West, 18th floor, Brooklyn, NY 11201', '50 Court St, Ste 1102, Brooklyn, NY 11201', '121 East 60th Street, Suite 9B, New York, NY 10022', '252 East 61st St, 1DN, New York, NY 10065', '50 Court St, Ste 1102, Brooklyn, NY 11201', '205 W 54th St, Suite 1B, New York, NY 10019', '36 E 31st St, Suite 701, New York, NY 10016', '77 Bowery, 7th Floor, New York, NY 10002', '128 Mott Street, Suite 202, New York, NY 10013', '535 5th Ave, 611, New York, NY 10017', '300 Cadman Plaza West, 18th floor, Brooklyn, NY 11201', 'Medical Offices of Manhattan - Midtown211 E 51st St, New York, NY 10022', '122 Fulton St., 6th Floor, New York, NY 10038', '123 William Street, 15th Floor, New York, NY 10038', '115 East 23rd Street, 10th Floor, New York, NY 10010'],
                   #'Details': details,
                   })

# Create a Pandas Excel writer using XlsxWriter as the engine.
#writer = pd.ExcelWriter('demo.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
#df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
#writer.save()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9164/2020340876.py in <module>
#       2
#       3 # dataframe Name and Age columns
# ...
