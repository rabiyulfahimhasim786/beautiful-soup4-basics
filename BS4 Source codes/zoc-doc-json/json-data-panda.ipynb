# %%
import requests
import pandas as pd

headers = {'Authorization' : 'eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9.eyJodHRwOi8vc2NoZW1hcy54bWxzb2FwLm9yZy93cy8yMDA1LzA1L2lkZW50aXR5L2NsYWltcy9uYW1lIjoiYWRtaW4iLCJleHAiOjIxMjcwNDQ1MTcsImlzcyI6Imh0dHBzOi8vZGV2ZWxvcGVyLmhlYWx0aHBvc3QuY29tIiwiYXVkIjoiaHR0cHM6Ly9kZXZlbG9wZXIuaGVhbHRocG9zdC5jb20ifQ.zNvR3WpI17CCMC7rIrHQCrnJg_6qGM21BvTP_ed_Hj8'}    
json_post = {"query":"","start":0,"rows":124,"selectedFilters":{"availability":[],"clinicalInterest":[],"distance":[20],"gender":["Both"],"hasOnlineScheduling":False,"insurance":[],"isMHMG":False,"language":[],"locationType":[],"lonlat":[-95.36,29.76],"onlineScheduling":["Any"],"specialty":["Gastroenterology"]}}
req = requests.post("https://api.memorialhermann.org/api/doctorsearch", json=json_post, headers=headers)
data = req.json()

data_all=[]
for doctor in data['docs']:
    doctor_name = (f"{doctor['Name']}")
    specialty = (f"{doctor['PrimarySpecialty']}")
    facility = (f"{doctor['PrimaryFacility']}")
    info = [doctor_name, specialty, facility]
    data_all.append({'Doctor Name':doctor_name,'Price':specialty,'Rating':facility})
df = pd.DataFrame(data_all)
df.to_csv('doctors1.csv',encoding='utf-8')

# %%
df
# Out:
#                       Doctor Name             Price  \
# 0           Dr. Isaac Raijman, MD  Gastroenterology
# 1             Dr. Gabriel Lee, MD  Gastroenterology
# 2             Dr. Dang Nguyen, MD  Gastroenterology
# 3    Dr. Harshinie Amaratunge, MD  Gastroenterology
# 4             Dr. Tanima Jana, MD  Gastroenterology
# ..                            ...               ...
# 119         Dr. Anna Gonzales, MD  Gastroenterology
# 120             Dr. Ali Dural, MD  Gastroenterology
# 121   Dr. Abraham Winkelstein, MD  Gastroenterology
# 122           Dr. Tawfiq Alam, MD  Gastroenterology
# 123    Dr. Nizar Charafeddine, MD  Gastroenterology
#
#                                       Rating
# 0      Memorial Hermann Texas Medical Center
# 1        Memorial Hermann Southeast Hospital
# 2      Memorial Hermann Texas Medical Center
# 3      Memorial Hermann Texas Medical Center
# 4      Memorial Hermann Texas Medical Center
# ..                                       ...
# 119  Memorial Hermann The Woodlands Hospital
# 120  Memorial Hermann The Woodlands Hospital
# 121  Memorial Hermann The Woodlands Hospital
# 122  Memorial Hermann The Woodlands Hospital
# 123                                     None
#
# [124 rows x 3 columns]

# %%
import requests
import pandas as pd

headers = {'Authorization' : 'eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9.eyJodHRwOi8vc2NoZW1hcy54bWxzb2FwLm9yZy93cy8yMDA1LzA1L2lkZW50aXR5L2NsYWltcy9uYW1lIjoiYWRtaW4iLCJleHAiOjIxMjcwNDQ1MTcsImlzcyI6Imh0dHBzOi8vZGV2ZWxvcGVyLmhlYWx0aHBvc3QuY29tIiwiYXVkIjoiaHR0cHM6Ly9kZXZlbG9wZXIuaGVhbHRocG9zdC5jb20ifQ.zNvR3WpI17CCMC7rIrHQCrnJg_6qGM21BvTP_ed_Hj8'}
json_post = {"query":"","start":0,"rows":10,"selectedFilters":{"availability":[],"clinicalInterest":[],"distance":[20],"gender":["Both"],"hasOnlineScheduling":False,"insurance":[],"isMHMG":False,"language":[],"locationType":[],"lonlat":[-95.36,29.76],"onlineScheduling":["Any"],"specialty":["Gastroenterology"]}}
req = requests.post("https://api.memorialhermann.org/api/doctorsearch", json=json_post, headers=headers)
data = req.json()
print(data['docs'])
df = pd.DataFrame(data['docs'])

df.to_csv('doctors2.csv', encoding='utf-8')
# Out:
# [{'PrimarySpecialty': 'Gastroenterology', 'PrimarySpecialtyUrl': 'gastroenterologists', 'PrimaryFacility': 'Memorial Hermann Texas Medical Center', 'Name': 'Dr. Isaac Raijman, MD', 'NPIID': '1689679557', 'MSOID': None, 'PCPID': '100000041789, 110000029306', 'Title': 'Dr.', 'FirstName': 'Isaac', 'MiddleName': 'L', 'LastName': 'Raijman', 'ImageUrl': '/-/media/memorial-hermann/global/images/physicians/isaac-l-raijman-md-1689679557', 'PhysicianImage': None, 'PreferredName': None, 'Gender': 'Male', 'Degree': 'MD', 'IsMHHSProvider': False, 'IsAcceptingNewPatients': True, 'IsOfferingVirtualVisits': False, 'IsMHPreferred': False, 'IsMHMG': False, 'IsUTP': False, 'IsMHMGPediatrics': False, 'ScheduleNowUrl': None, 'IsAvailableNext24Hours': False, 'IsAvailableNext7Days': False, 'IsAvailableNext30Days': False, 'HealthPostId': None, 'HealthPostTelemedicineLocationId': None, 'Facilities': None, 'Specialties': None, 'locationtypes': None, 'healthpost_location_ids': None, 'office_address_ids': ['7aab6fb52dd64af1814137c8af583efd'], 'office_address': ['--------------count : 1', 'id : 7aab6fb52dd64af1814137c8af583efd', 'AddressLine1 : 4100 S Sheperd Dr', 'AddressLine2 : ', 'City : Houston', 'State : TX', 'PostalCode : 77098', 'phone : (713) 795-4444', 'fax : Houston', 'geocoordinate : 29.729656,-95.410910', 'hplocid : ', 'LocationXid : ', 'LocationXidInternal : ', 'IsReferringLocation : False'], 'locations': None, 'availabilities': {'hasR1Scheduling': False, 'appointmentsByDate': None}, 'offices': [{'id': '7aab6fb52dd64af1814137c8af583efd', 'name': None, 'AddressLine1': '4100 S Sheperd Dr', 'AddressLine2': '', 'City': 'Houston', 'State': 'TX', 'PostalCode': '77098', 'phone': '(713) 795-4444', 'fax': 'Houston', 'address': None, 'distance': '3.70 miles', 'directionsURL': 'https://www.google.com/maps/dir/29.76,-95.36/4100+S+Sheperd+Dr,+,+Houston,+TX,+77098/', 'hp_location_ids': None, 'geocoordinate': '29.729656,-95.410910', 'hplocid': '', 'isTelemedicine': False, 'LocationXid': None, 'IsReferringLocation': False}], 'url': '/doctors/gastroenterologists/dr-isaac-raijman-md-1689679557', 'AverageRating': None, 'ReviewCount': '0', 'Reviews': None, 'coords': '29.729656,-95.410910', 'ItemName': 'Isaac Raijman Nid_1689679557 Pid_646506 Mid_004450', 'ReasonsForVisit': None, 'ReferralSpecialties': None, 'ProviderXId': ['0044501689679557'], 'HasAnyOfficeWithLocationXidInternal': False, 'HasOnlineScheduling': False}, {'PrimarySpecialty': 'Gastroenterology', 'PrimarySpecialtyUrl': 'gastroenterologists', 'PrimaryFacility': 'Memorial Hermann Southeast Hospital', 'Name': 'Dr. Gabriel Lee, MD', 'NPIID': '1265636831', 'MSOID': None, 'PCPID': '110000023031, 110000028952', 'Title': 'Dr.', 'FirstName': 'Gabriel', 'MiddleName': 'Hyung', 'LastName': 'Lee', 'ImageUrl': None, 'PhysicianImage': None, 'PreferredName': None, 'Gender': 'Male', 'Degree': 'MD', 'IsMHHSProvider': False, 'IsAcceptingNewPatients': True, 'IsOfferingVirtualVisits': False, 'IsMHPreferred': False, 'IsMHMG': False, 'IsUTP': False, 'IsMHMGPediatrics': False, 'ScheduleNowUrl': None, 'IsAvailableNext24Hours': False, 'IsAvailableNext7Days': False, 'IsAvailableNext30Days': False, 'HealthPostId': None, 'HealthPostTelemedicineLocationId': None, 'Facilities': None, 'Specialties': None, 'locationtypes': None, 'healthpost_location_ids': None, 'office_address_ids': ['78c1b6c73dc44912adb86a8b09303276', 'b5ee9d2fecc646578ca75276802a3b49'], 'office_address': ['--------------count : 1', 'id : 78c1b6c73dc44912adb86a8b09303276', 'AddressLine1 : 4100 S Sheperd Dr', 'AddressLine2 : ', 'City : Houston', 'State : TX', 'PostalCode : 77098', 'phone : (214) 424-2200', 'fax : Houston', 'geocoordinate : 29.729656,-95.410910', 'hplocid : ', 'LocationXid : ', 'LocationXidInternal : ', 'IsReferringLocation : False', '--------------count : 2', 'id : b5ee9d2fecc646578ca75276802a3b49', 'AddressLine1 : 2060 Space Park Dr, Ste 200', 'AddressLine2 : ', 'City : Houston', 'State : TX', 'PostalCode : 77058', 'phone : (281) 333-2588', 'fax : ...

# %%
df
# Out:
#                       Doctor Name             Price  \
# 0           Dr. Isaac Raijman, MD  Gastroenterology
# 1             Dr. Gabriel Lee, MD  Gastroenterology
# 2             Dr. Dang Nguyen, MD  Gastroenterology
# 3    Dr. Harshinie Amaratunge, MD  Gastroenterology
# 4             Dr. Tanima Jana, MD  Gastroenterology
# ..                            ...               ...
# 119         Dr. Anna Gonzales, MD  Gastroenterology
# 120             Dr. Ali Dural, MD  Gastroenterology
# 121   Dr. Abraham Winkelstein, MD  Gastroenterology
# 122           Dr. Tawfiq Alam, MD  Gastroenterology
# 123    Dr. Nizar Charafeddine, MD  Gastroenterology
#
#                                       Rating
# 0      Memorial Hermann Texas Medical Center
# 1        Memorial Hermann Southeast Hospital
# 2      Memorial Hermann Texas Medical Center
# 3      Memorial Hermann Texas Medical Center
# 4      Memorial Hermann Texas Medical Center
# ..                                       ...
# 119  Memorial Hermann The Woodlands Hospital
# 120  Memorial Hermann The Woodlands Hospital
# 121  Memorial Hermann The Woodlands Hospital
# 122  Memorial Hermann The Woodlands Hospital
# 123                                     None
#
# [124 rows x 3 columns]
