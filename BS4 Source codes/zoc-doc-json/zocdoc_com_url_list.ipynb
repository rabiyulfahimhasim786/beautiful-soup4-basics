# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:96.0) Gecko/20100101 Firefox/96.0'}
HOST = 'https://www.zocdoc.com/'
PAGE = 'search?filters=%7B%7D&dr_specialty=98&reason_visit=11&address=Houston%2C%20TX&searchType=specialty&offset=0&insurance_carrier=-1&insurance_plan=-1&search_query=Dentist&ppsSelectionId=4320232f-4047-467a-89c5-4225204ba506&longitude=-95.3698028&latitude=29.7604267&city=Houston&locationType=placemark&state=TX&referrerType=ListingPage&searchQueryGuid=&component=ListingSearchButton'
with requests.Session() as session:
    (r := session.get(HOST, headers=headers)).raise_for_status()
    (r := session.get(f'{HOST}/{PAGE}', headers=headers)).raise_for_status()

# %%
print(r.text)
# Out:
# <!doctype html>
#     <html lang="en">
#         <head>
#             <meta name="msapplication-TileImage" content="/images/rebrand/favicon/favicon_large.png" />
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />
# <meta name="format-detection" content="telephone=no" />
#
#             <link rel="shortcut icon" type="image/x-icon" href="https://www.zocdoc.com/favicon.ico" sizes="32x32" />
# <link rel="dns-prefetch" href="//api.zocdoc.com" />
# <link rel="dns-prefetch" href="//www.zocdoc.com" />
# <link rel="preconnect" href="https://api.zocdoc.com" />
# <link rel="preconnect" href="https://www.zocdoc.com" />
# <link rel="dns-prefetch" href="//dd.zocdoc.com" />
# <link rel="preconnect" href="https://dd.zocdoc.com" />
# <link rel="dns-prefetch" href="//js.captcha-display.com" />
# <link rel="preconnect" href="https://js.captcha-display.com" />
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="/images/rebrand/favicon/favicon_large.png" name="msapplication-TileImage"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.zocdoc.com/favicon.ico" rel="shortcut icon" sizes="32x32" type="image/x-icon"/>
#   <link href="//api.zocdoc.com" rel="dns-prefetch"/>
#   <link href="//www.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://api.zocdoc.com" rel="preconnect"/>
#   <link href="https://www.zocdoc.com" rel="preconnect"/>
#   <link href="//dd.zocdoc.com" rel="dns-prefetch"/>
#   <link href="https://dd.zocdoc.com" rel="preconnect"/>
#   <link href="//js.captcha-display.com" rel="dns-prefetch"/>
#   <link href="https://js.captcha-display.com" rel="preconnect"/>
#   <link href="//d1uhlocgth3qyq.cloudfront.net" rel="dns-prefetch"/>
# ...

# %%
url_list = []
for a in soup.find("div", class_="fs-unmask").find_all("a"):
  # url_list.append(a["href"])
  print(a)
# Out:
# <a class="sc-dWRHGJ ioKtmT sc-EJAja jPnAXz patient-web-app__sc-1dvlspq-0 patient-web-app__sc-1e1omv5-7 fvjpYT ehJbcF" data-test="static-header-logo" href="/" title="Back to homepage"></a>
# <a class="sc-dWRHGJ ioKtmT sc-EJAja jPnAXz patient-web-app__sc-1e1omv5-14 jYthJO" data-test="header-help-link" href="https://support.zocdoc.com/patients/s/contactsupport" rel="noopener noreferrer" target="_blank">Help</a>
# <a class="sc-dWRHGJ ioKtmT sc-EJAja jPnAXz patient-web-app__sc-1e1omv5-14 jYthJO" data-test="header-cta" href="/join?utm_medium=organicpro&amp;utm_source=website&amp;utm_campaign=PatientSite_Header">List your practice on Zocdoc</a>
# <a class="patient-web-app__sc-esebpo-0 patient-web-app__sc-1qzdqoy-2 bVJPCr hROJaB" role="button" tabindex="0">Log in / Sign up</a>
# ...

# %%
link = soup.find('div',class_='fs-unmask')

url_list = link.find('a').get('href')

urldata = []
for url_list in link.find_all('a', class_='sc-edKBRp coAOky'):
    # print (url_list.get('href'))
    abc = url_list.get('href')
    efd = 'https://www.zocdoc.com'
    additionurl = efd+abc
    print(additionurl)
    urldata.append(additionurl)
# Out:
# https://www.zocdoc.com/dentist/vicky-matayoshi-dds-405410?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage
# https://www.zocdoc.com/dentist/david-nguyen-dmd-207843?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage
# https://www.zocdoc.com/dentist/payton-canchola-dds-392804?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage
# https://www.zocdoc.com/dentist/kyunglim-chae-dds-301927?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage
# https://www.zocdoc.com/dentist/pasha-noorian-dmd-381329?LocIdent=188571&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage
# ...

# %%
print(urldata)
# Out:
# ['https://www.zocdoc.com/dentist/vicky-matayoshi-dds-405410?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage', 'https://www.zocdoc.com/dentist/david-nguyen-dmd-207843?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage', 'https://www.zocdoc.com/dentist/payton-canchola-dds-392804?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage', 'https://www.zocdoc.com/dentist/kyunglim-chae-dds-301927?LocIdent=172205&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage', 'https://www.zocdoc.com/dentist/pasha-noorian-dmd-381329?LocIdent=188571&reason_visit=11&insuranceCarrier=-1&insurancePlan=-1&dr_specialty=98&isNewPatient=true&referrerType=ListingPage', 'https://www.zocdoc.com/dentist/omar-amin-dds-360521?LocIde
# ...
