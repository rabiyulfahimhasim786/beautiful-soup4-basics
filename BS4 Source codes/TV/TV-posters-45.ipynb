# %%
import requests, bs4
from bs4 import BeautifulSoup
from csv import writer

# %%
url = "https://posterswholesale.americommerce.com/store/c/28-TV.aspx"
page = requests.get(url)
page
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html><html xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml">\n<head>\n\t<title>TV</title>\n\t<meta name="description" content="TV">\n\t<meta name="keywords" content="TV, , TV">\n\t\n\t<link rel="canonical" href="http://www.posterswholesale.com/store/c/28-TV.aspx">\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8">\n<!--NUMBERED_PAGING_CSS--><link type="text/css" rel="stylesheet" href="/store/inc/style/ac.pagebynumber.css">\n\n<!--AC_CORE_CSS--><link type="text/css" rel="stylesheet" href="/store/inc/style/ac.core.css">\n\n<!--JQUERYUI_CORE--><link type="text/css" rel="stylesheet" href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.min.css">\n<!--FRONTEND_AUTOCOMPLETE_CSS--><link rel="stylesheet" type="text/css" href="/store/inc/style/jquery.ui.autocomplete.css" />\n<script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>\n<script ty
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title>
#    TV
#   </title>
#   <meta content="TV" name="description"/>
#   <meta content="TV, , TV" name="keywords"/>
#   <link href="http://www.posterswholesale.com/store/c/28-TV.aspx" rel="canonical"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <!--NUMBERED_PAGING_CSS-->
#   <link href="/store/inc/style/ac.pagebynumber.css" rel="stylesheet" type="text/css"/>
#   <!--AC_CORE_CSS-->
#   <link href="/store/inc/style/ac.core.css" rel="stylesheet" type="text/css"/>
#   <!--JQUERYUI_CORE-->
#   <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
#   <!--FRONTEND_AUTOCOMPLETE_CSS-->
#   <link href="/store/inc/style/jquery.ui.autocomplete.css" rel="stylesheet" type="text/css">
# ...

# %%
movies_html = soup.find_all('a', class_='h5 color-inherit')

movie_titles = []

for title in movies_html:
 movie_titles.append(title.text.strip())
print(movie_titles)
# Out:
# ['Better Call Saul', 'Bob Ross', 'Breaking Bad', 'Cobra Kai', 'Curb Your Enthusiasm', 'Fresh Prince', 'Friends', 'Friends', 'Friends', 'Friends', 'Loki', 'Monty Python', 'Parks & Recreation', 'Power Rangers', 'Rick and Morty', 'Rick and Morty', 'Rick and Morty 12x24"', 'Seinfeld George Costanza', 'Seinfeld Kramer', 'Sopranos', 'Squid Game', 'Star Trek', 'Star Trek', 'Stranger Things 1', 'Stranger Things 1', 'Stranger Things 2', 'Stranger Things 2', 'Stranger Things 3', 'Stranger Things 3', 'The Bold Type', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Office', 'The Office', 'The Office', 'Twilight Zone', "Wayne's World", 'Wonder Woman', 'X-Files I Want To Believe']

# %%
stocks_html = soup.find_all('span', class_='CategoryProductAvailability')

stock_titles = []

for title in stocks_html:
 stock_titles.append(title.text.strip())
print(stock_titles)
# Out:
# ['Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: Temporarily Out of Stock', 'Availability: Temporarily Out of Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: Temporarily Out of Stock', 'Availability: Temporarily Out of Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: Temporarily Out of Stock', 'Availability: Temporarily Out of Stock', 'Availability: In Stock', 'Availability: In Stock', 'Availability: Te
# ...

# %%
items_html = soup.find_all('span', class_='CategoryProductItemNr')

item_titles = []

for title in items_html:
 item_titles.append(title.text.strip())
print(item_titles)
# Out:
# ['Item #: 54260 -', 'Item #: 52860 -', 'Item #: 50821 -', 'Item #: 54275 -', 'Item #: 54390 -', 'Item #: 53327 -', 'Item #: 51806 -', 'Item #: 50227 -', 'Item #: 51887 -', 'Item #: 51886 -', 'Item #: 54362 -', 'Item #: 53088 -', 'Item #: 51024 -', 'Item #: 53970 -', 'Item #: 51848 -', 'Item #: 52264 -', 'Item #: 54202 -', 'Item #: 46525 -', 'Item #: 48181 -', 'Item #: 54389 -', 'Item #: 54385 -', 'Item #: 51133 -', 'Item #: 54407 -', 'Item #: 51891 -', 'Item #: 51993 -', 'Item #: 52272 -', 'Item #: 52443c -', 'Item #: 53248 -', 'Item #: 53273b -', 'Item #: 53321 -', 'Item #: 53978 -', 'Item #: 53979 -', 'Item #: 53989 -', 'Item #: 53988 -', 'Item #: 53984b -', 'Item #: 53990 -', 'Item #: 54252 -', 'Item #: 54251 -', 'Item #: 54162 -', 'Item #: 48757 -', 'Item #: 53111b -', 'Item #: 54256 -', 'Item #: 53185 -', 'Item #: 50423 -', 'Item #: 27250 -']

# %%
price_html = soup.find_all('span', class_='CategoryProductRetailPrice')

price_titles = []

for title in price_html:
 price_titles.append(title.text.strip())
print(price_titles)
# Out:
# ['$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99']

# %%
import pandas as pd
writer = pd.ExcelWriter('TV-poster45.xlsx', engine='xlsxwriter')
writer.save()

# %%
import pandas as pd

# dataframe Name and Age columns
df = pd.DataFrame({#'Movie Title': ['Better Call Saul', 'Bob Ross', 'Breaking Bad', 'Cobra Kai', 'Curb Your Enthusiasm', 'Fresh Prince', 'Friends', 'Friends', 'Friends', 'Friends', 'Loki', 'Monty Python', 'Parks & Recreation', 'Power Rangers', 'Rick and Morty', 'Rick and Morty', 'Rick and Morty 12x24"', 'Seinfeld George Costanza', 'Seinfeld Kramer', 'Sopranos', 'Squid Game', 'Star Trek', 'Star Trek', 'Stranger Things 1', 'Stranger Things 1', 'Stranger Things 2', 'Stranger Things 2', 'Stranger Things 3', 'Stranger Things 3', 'The Bold Type', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Mandalorian', 'The Office', 'The Office', 'The Office', 'Twilight Zone', "Wayne's World", 'Wonder Woman', 'X-Files I Want To Believe'],
                   'Stock': ['In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'Temporarily Out of Stock', 'Temporarily Out of Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock'],})
                   #'Minimum Quantity' : ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', ],
                   #'Size' : ['36 In x 24 In', '34 In x 22 In', '36 In x 24 In', '22 In x 34 In', '36 In x 24 In', '12 In x 24 In', '36 In x 24 In', '24 In x 36 In', '24 In x 36 In', '36 In x 24 In', '22 In x 34 In', '22 In x 34 In', '36 In x 24 In', '36 In x 24 In', '36 In x 24 In', '36 In x 24 In', '12 In x 24 In', '36 In x 24 In', '24 In x 36 In', '36 In x 24 In', '24 In x 36 In', '36 In x 24 In', '36 In x 24 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In', '12 In x 24 In', '22 In x 34 In', '22 In x 34 In', '34 In x 22 In', '34 In x 22 In', '22 In x 34 In', '22 In x 34 In', '22 In x 34 In', '22 In x 34 In', '22 In x 34 In', '22 In x 34 In', '34 In x 22 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In', '24 In x 36 In'],
                   #'Item Number': ['54260', '52860', '50821', '54275', '54390', '53327', '51806', '50227', '51887', '51886', '54362', '53088', '51024', '53970', '51848', '52264', '54202', '46525', '48181', '54389', '54385', '51133', '54407', '51891', '51993', '52272', '52443c', '53248', '53273b', '53321', '53978', '53979', '53989', '53988', '53984b', '53990', '54252', '54251', '54162', '48757', '53111b', '54256', '53185', '50423', '27250'],
                   #'Retail Price': ['$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$7.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99', '$8.99']})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('TV-poster-stock.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
