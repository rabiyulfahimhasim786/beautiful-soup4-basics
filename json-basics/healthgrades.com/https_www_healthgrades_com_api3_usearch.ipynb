# %%
import requests

# %%
BASE_URL = 'https://www.healthgrades.com/api3/usearch'

# %%
params = {
    'userLocalTime':'22:37',
    'what':'Family+Medicine', #Dentistry, Infectious+Disease+Medicine, Internal Medicine, Counseling
    'where':'Houston, TX',
    #'pt':'40.720901, -74.008904',
    'sort.provider':'bestmatch',
    'category':'provider',
    'sessionId':'S4e4d',
    'requestId':'a948ae51ff1009d6',
    'pageSize.provider':'239',#239
    'pageNum':'1',#11
    'isFirstRequest':'true',
    'debug':'false',
    'isAtlas':'true',
    'action':'refresh',
    #'neCorner':'40.744526282819244,-73.99060337556104',
    #'swCorner':'40.69723118200452,-74.02724113269275'
    }

# %%
r = requests.get(BASE_URL, params=params)
print(r.text)
# Out:
# {"search":{"filterData":[{"allValues":[{"displayText":"Principal Financial Group","displayCount":"284","value":"HPY0000627","data":"HPY0000627","isSelected":false,"isDefaultSelection":false,"id":"HPY0000627"},{"displayText":"Dental Network of America","displayCount":"276","value":"HPY00004A2","data":"HPY00004A2","isSelected":false,"isDefaultSelection":false,"id":"HPY00004A2"},{"displayText":"Guardian","displayCount":"274","value":"HPY000045D","data":"HPY000045D","isSelected":false,"isDefaultSelection":false,"id":"HPY000045D"},{"displayText":"Ameritas","displayCount":"262","value":"HPY00006E5","data":"HPY00006E5","isSelected":false,"isDefaultSelection":false,"id":"HPY00006E5"},{"displayText":"Delta Dental","displayCount":"260","value":"HPY000054F","data":"HPY000054F","isSelected":false,"isDefaultSelection":false,"id":"HPY000054F"},{"displayText":"UnitedHealthCare","displayCount":"251","value":"HPY0000619","data":"HPY0000619","isSelected":false,"isDefaultSelection":false,"id":"HPY0000619"},{"displayText":"Humana","displayCount":"246","value":"HPY0000453","data":"HPY0000453","isSelected":false,"isDefaultSelection":false,"id":"HPY0000453"},{"displayText":"Aetna","displayCount":"219","value":"HPY00006D9","data":"HPY00006D9","isSelected":false,"isDefaultSelection":false,"id":"HPY00006D9"},{"displayText":"MetLife","displayCount":"199","value":"HPY0000692","data":"HPY0000692","isSelected":false,"isDefaultSelection":false,"id":"HPY0000692"},{"displayText":"DenteMax","displayCount":"167","value":"HPY0000671","data":"HPY0000671","isSelected":false,"isDefaultSelection":false,"id":"HPY0000671"},{"displayText":"Total Dental Administrators PPO","displayCount":"156","value":"HPY0000776","data":"HPY0000776","isSelected":false,"isDefaultSelection":false,"id":"HPY0000776"},{"displayText":"United Concordia","displayCount":"144","value":"HPY0000708","data":"HPY0000708","isSelected":false,"isDefaultSelection":false,"id":"HPY0000708"},{"displayText":"Cigna","displayCount":"92","value":"HPY00006F7","data":"HPY00006F7","isSelected":false,"isDefaultSelection":false,"id":"HPY00006F7"},{"displayText":"Ambetter","displayCount":"74","value":"HPY0000767","data":"HPY0000767","isSelected":false,"isDefaultSelection":false,"id":"HPY0000767"},{"displayText":"Coventry Health Care","displayCount":"62","value":"HPY000040F","data":"HPY000040F","isSelected":false,"isDefaultSelection":false,"id":"HPY000040F"},{"displayText":"Assurant Health","displayCount":"36","value":"HPY0000555","data":"HPY0000555","isSelected":false,"isDefaultSelection":false,"id":"HPY0000555"},{"displayText":"Blue Cross Blue Shield of Texas","displayCount":"23","value":"HPY0000655","data":"HPY0000655","isSelected":false,"isDefaultSelection":false,"id":"HPY0000655"},{"displayText":"Blue Cross Blue Shield","displayCount":"22","value":"HPY00005A3","data":"HPY00005A3","isSelected":false,"isDefaultSelection":false,"id":"HPY00005A3"},{"displayText":"Government Employees Health Association (GEHA)","displayCount":"22","value":"HPY00004FB","data":"HPY00004FB","isSelected":false,"isDefaultSelection":false,"id":"HPY00004FB"},{"displayText":"Amerigroup (Wellpoint)","displayCount":"17","value":"HPY0000461","data":"HPY0000461","isSelected":false,"isDefaultSelection":false,"id":"HPY0000461"},{"displayText":"Dental Select","displayCount":"16","value":"HPY00005AD","data":"HPY00005AD","isSelected":false,"isDefaultSelection":false,"id":"HPY00005AD"},{"displayText":"DentaQuest","displayCount":"14","value":"HPY00004DE","data":"HPY00004DE","isSelected":false,"isDefaultSelection":false,"id":"HPY00004DE"},{"displayText":"Dentegra","displayCount":"14","value":"HPY0000826","data":"HPY0000826","isSelected":false,"isDefaultSelection":false,"id":"HPY0000826"},{"displayText":"Medicaid","displayCount":"14","value":"HPY0000637","data":"HPY0000637","isSelected":false,"isDefaultSelection":false,"id":"HPY0000637"},{"displayText":"Molina Healthcare","displayCount":"14","value":"HPY00006AE","data":"HPY00006AE","isSelected":false,"is ...

# %%
r.raise_for_status()

# %%
dentists = r.json()['search']['searchResults']['provider']['results']

# %%
for dentist in dentists:
  print(dentist['displayName'])
  print(dentist['specialistDesc'])
  print(dentist['addresses'][0]['address1'])
  print(dentist['addresses'][0]['officeCode'])
  print(dentist['addresses'][0]['officeGuid'])
  print(dentist['addresses'][0]['location']['cityName'])
  print(dentist['addresses'][0]['location']['cityAndState'])
  print(dentist['addresses'][0]['location']['cityStateZipBestMatch'])
  # print(dentist['addresses'][0]['location']['cityName']['cityAndState'])
  # print(dentist['addresses'][0]['location']['cityName']['cityStateZipBestMatch'])
# Out:
# Dr. John Ma, DDS
# ['Dentist']
# 2240 Navigation Blvd Ste 300
# OYX664K
# 3658594F-3436-004B-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77003
# Dr. Bianca Williams, DDS
# ['Dentist']
# 2240 Navigation Blvd Ste 300
# OYX664K
# 3658594F-3436-004B-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77003
# Dr. Charles Sutherland, DDS
# ['Dentist', 'Endodontics Specialist']
# 333 Clay St Ste 100
# OO5PMR3
# 50354F4F-524D-0033-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# Dr. Jonathan Penchas, DMD
# ['Dentist', 'Denturist']
# 808 Travis St # Tunnel
# OY56JP8
# 3635594F-504A-0038-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# Dr. James May, DDS
# ['Orthodontics Specialist', 'Dentist']
# 102 Heights Blvd Ste A
# OY55QCL
# 3535594F-4351-004C-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Cynthia Corral, DDS
# ['Dentist']
# 2313 Edwards St
# OOVLW5N
# 4C564F4F-3557-004E-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Shirley Parikh, DDS
# ['Dentist', 'Orthodontics Specialist', 'Periodontic Specialist']
# 701 Shepherd Dr Ste 102
# OOVPGLB
# 50564F4F-4C47-0042-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Sabina Falkin, DDS
# ['Dentist']
# 22545 Sh # 249
# QCCDTAB318
# 44434351-4154-3342-3138-000000000000
# Houston
# Houston, TX
# Houston, TX 77070
# Dr. Ramine Nabizadeh, DDS
# ['Dentist']
# 2450 Louisiana Houston Tx # 77006
# VH3NHDF787
# 4E334856-4448-3746-3837-000000000000
# Houston
# Houston, TX
# Houston, TX 77006
# Dr. Kyle Tran, DDS
# ['Dentist']
# 5656 Kelley Street 5656 Kelley St
# L42RQRB246
# 5232344C-5251-3242-3436-000000000000
# Houston
# Houston, TX
# Houston, TX 77026
# Dr. George Glauser, DDS
# ['Dentist']
# 4550 Fondern Rd Ste 100
# CQTCL0G977
# 43545143-304C-3947-3737-000000000000
# Houston
# Houston, TX
# Houston, TX 77063
# Dr. Glenda Owen, DDS
# ['Dentist']
# 5151 Katy Fwy Ste 203
# OYYVXPD
# 5659594F-5058-0044-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Viviane Bouchara, DDS
# ['Dentist']
# 5681 Fairmont Pkwy
# OY57842
# 3735594F-3438-0032-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77070
# Dr. William Eng, DDS
# ['Dentist', 'Endodontics Specialist']
# 2101 Crawford St Ste 107
# OON8R6P
# 384E4F4F-3652-0050-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# Dr. Nguyet Dang, DDS
# ['Dentist']
# 1202 Elgin St # A
# OOMQX56
# 514D4F4F-3558-0036-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77004
# Dr. Gary Dennis, DDS
# ['Dentist']
# 1911 Taylor St
# OO8MP6J
# 4D384F4F-3650-004A-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Ahmed Eldin, DDS
# ['Dentist']
# 1911 Taylor St
# OO8MP6J
# 4D384F4F-3650-004A-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Walter Ackah, DMD
# ['Dentist']
# 1911 Taylor St
# OO8MP6J
# 4D384F4F-3650-004A-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# Dr. Rami Alsaleh, DMD
# ['Dentist', 'Oral & Maxillofacial Surgery Specialist', 'Orthodontics Specialist', 'Endodontics Specialist', 'Periodontic Specialist', 'Denturist']
# 3407 Montrose Blvd Ste B4
# OOVCNHH
# 43564F4F-484E-0048-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77006
# Dr. Nester Arellano, DDS
# ['Dentist']
# 3303 N Main St Unit 1
# OO5DSVV
# 44354F4F-5653-0056-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77009
# Dr. Judith Mabrito, DDS
# ['Dentist']
# 700 Louisiana St Ste 2430
# OO5W52B
# 57354F4F-3235-0042-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# Dr. Alicia Valentini, DDS
# ['Periodontic Specialist', 'Dentist']
# 650 Heights Blvd
# OYXL8BY
# 4C58594F-4238-0059-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007

# %%
#

# %%
import pandas as pd
data_all=[]
for dentist in dentists:
  doctor_name = dentist['displayName']
  specialty = "Family Practitioner" #print(dentist['specialistDesc'])
  address =dentist['addresses'][0]['address1']
  officeCode = dentist['addresses'][0]['officeCode']
  officeGuid = dentist['addresses'][0]['officeGuid']
  cityName =dentist['addresses'][0]['location']['cityName']
  cityAndState = dentist['addresses'][0]['location']['cityAndState']
  cityStateZipBestMatch = dentist['addresses'][0]['location']['cityStateZipBestMatch']
  data_all.append({'Doctor Name':doctor_name,'Price':specialty,'Address': address, 'OfficeCode': officeCode, 'OfficeGuid': officeGuid, 'CityName': cityName, 'CityAndState': cityAndState, 'CityStateZipBestMatch':cityStateZipBestMatch})
df = pd.DataFrame(data_all)
df.to_csv('products1.csv',encoding='utf-8')
  # print(dentist['addresses'][0]['location']['cityName']['cityAndState'])
  # print(dentist['addresses'][0]['location']['cityName']['cityStateZipBestMatch'])

# %%
#

# %%
#

# %%
#
