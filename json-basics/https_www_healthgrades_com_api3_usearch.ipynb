# %%
import requests

# %%
BASE_URL = 'https://www.healthgrades.com/api3/usearch'

# %%
params = {
    'userLocalTime':'22:37',
    'what':'Nursing+(Nurse+Practitioner)', #'Family+Medicine', 'General+Medical+Practice', 'Adult+Medicine', Nursing+(Nurse+Practitioner), Occupational+Medicine #Dentistry, Infectious+Disease+Medicine, Internal Medicine, Counseling
    'where':'Houston, TX',
    #'pt':'40.720901, -74.008904',
    'sort.provider':'bestmatch',
    'category':'provider',
    'sessionId':'S4e4d',
    'requestId':'a948ae51ff1009d6',
    'pageSize.provider':'239',#239
    'pageNum':'1',#11
    'isFirstRequest':'true',
    'debug':'false',
    'isAtlas':'true',
    'action':'refresh',
    #'neCorner':'40.744526282819244,-73.99060337556104',
    #'swCorner':'40.69723118200452,-74.02724113269275'
    }

# %%
r = requests.get(BASE_URL, params=params)
print(r.text)
# Out:
# {"search":{"filterData":[{"allValues":[{"displayText":"Blue Cross Blue Shield of Texas","displayCount":"941","value":"HPY0000655","data":"HPY0000655","isSelected":false,"isDefaultSelection":false,"id":"HPY0000655"},{"displayText":"Cigna","displayCount":"940","value":"HPY00006F7","data":"HPY00006F7","isSelected":false,"isDefaultSelection":false,"id":"HPY00006F7"},{"displayText":"Blue Cross Blue Shield","displayCount":"932","value":"HPY00005A3","data":"HPY00005A3","isSelected":false,"isDefaultSelection":false,"id":"HPY00005A3"},{"displayText":"First Health (Coventry Health Care)","displayCount":"858","value":"HPY0000734","data":"HPY0000734","isSelected":false,"isDefaultSelection":false,"id":"HPY0000734"},{"displayText":"Humana","displayCount":"541","value":"HPY0000453","data":"HPY0000453","isSelected":false,"isDefaultSelection":false,"id":"HPY0000453"},{"displayText":"MultiPlan","displayCount":"398","value":"HPY00004D8","data":"HPY00004D8","isSelected":false,"isDefaultSelection":false,"id":"HPY00004D8"},{"displayText":"Aetna","displayCount":"352","value":"HPY00006D9","data":"HPY00006D9","isSelected":false,"isDefaultSelection":false,"id":"HPY00006D9"},{"displayText":"Ambetter","displayCount":"208","value":"HPY0000767","data":"HPY0000767","isSelected":false,"isDefaultSelection":false,"id":"HPY0000767"},{"displayText":"Humana Health Plan of Texas","displayCount":"62","value":"HPY00005D8","data":"HPY00005D8","isSelected":false,"isDefaultSelection":false,"id":"HPY00005D8"},{"displayText":"CareFirst Blue Cross Blue Shield","displayCount":"25","value":"HPY000069E","data":"HPY000069E","isSelected":false,"isDefaultSelection":false,"id":"HPY000069E"},{"displayText":"Anthem Blue Cross Blue Shield","displayCount":"7","value":"HPY0000696","data":"HPY0000696","isSelected":false,"isDefaultSelection":false,"id":"HPY0000696"},{"displayText":"UnitedHealthCare","displayCount":"5","value":"HPY0000619","data":"HPY0000619","isSelected":false,"isDefaultSelection":false,"id":"HPY0000619"},{"displayText":"Amerihealth","displayCount":"3","value":"HPY000040A","data":"HPY000040A","isSelected":false,"isDefaultSelection":false,"id":"HPY000040A"},{"displayText":"Anthem","displayCount":"3","value":"HPY0000768","data":"HPY0000768","isSelected":false,"isDefaultSelection":false,"id":"HPY0000768"},{"displayText":"Health Net","displayCount":"3","value":"HPY00006D4","data":"HPY00006D4","isSelected":false,"isDefaultSelection":false,"id":"HPY00006D4"},{"displayText":"Amerigroup (Wellpoint)","displayCount":"2","value":"HPY0000461","data":"HPY0000461","isSelected":false,"isDefaultSelection":false,"id":"HPY0000461"},{"displayText":"Harvard Pilgrim Health Care","displayCount":"2","value":"HPY0000474","data":"HPY0000474","isSelected":false,"isDefaultSelection":false,"id":"HPY0000474"},{"displayText":"HealthPlus","displayCount":"2","value":"HPY0000660","data":"HPY0000660","isSelected":false,"isDefaultSelection":false,"id":"HPY0000660"},{"displayText":"HealthPlus Amerigroup","displayCount":"2","value":"HPY000042B","data":"HPY000042B","isSelected":false,"isDefaultSelection":false,"id":"HPY000042B"},{"displayText":"Horizon Blue Cross Blue Shield of New Jersey","displayCount":"2","value":"HPY00005A8","data":"HPY00005A8","isSelected":false,"isDefaultSelection":false,"id":"HPY00005A8"},{"displayText":"Husky Health","displayCount":"2","value":"HPY0000432","data":"HPY0000432","isSelected":false,"isDefaultSelection":false,"id":"HPY0000432"},{"displayText":"inHealth","displayCount":"2","value":"HPY00004D3","data":"HPY00004D3","isSelected":false,"isDefaultSelection":false,"id":"HPY00004D3"},{"displayText":"Medica","displayCount":"2","value":"HPY0000565","data":"HPY0000565","isSelected":false,"isDefaultSelection":false,"id":"HPY0000565"},{"displayText":"Medicaid","displayCount":"2","value":"HPY0000637","data":"HPY0000637","isSelected":false,"isDefaultSelection":false,"id":"HPY0000637"},{"displayText":"Medicare","displayCount":"2","value":"HPY0000625","data":"HPY0000625","isSelected":fa ...

# %%
r.raise_for_status()

# %%
dentists = r.json()['search']['searchResults']['provider']['results']

# %%
for dentist in dentists:
  print(dentist['displayName'])
  print(dentist['specialistDesc'])
  print(dentist['addresses'][0]['address1'])
  print(dentist['addresses'][0]['officeCode'])
  print(dentist['addresses'][0]['officeGuid'])
  print(dentist['addresses'][0]['location']['cityName'])
  print(dentist['addresses'][0]['location']['cityAndState'])
  print(dentist['addresses'][0]['location']['cityStateZipBestMatch'])
  print('https:'+dentist['images'][0]['url'])
  # print(dentist['addresses'][0]['location']['cityName']['cityAndState'])
  # print(dentist['addresses'][0]['location']['cityName']['cityStateZipBestMatch'])
# Out:
# Sarah Cooper, APRN
# ['Nurse Practitioner']
# 4414 SW College Rd Unit 1462
# OY4WP4P
# 5734594F-3450-0050-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 34474
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Wanda Hilliard, APRN-BC
# ['Nurse Practitioner', 'Registered Nurse', 'Clinical Nurse Specialist']
# 5225 Katy Fwy Ste 650
# OY56FGH
# 3635594F-4746-0048-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# https://photos.healthgrades.com/img/prov/3/P/Y/3PYQW_w60h80_v6630.jpg
# Roseline Onwuchuruba, APRN
# ['Nurse Practitioner']
# 1310 Prairie St Ste 990
# OY5YM9D
# 5935594F-394D-0044-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Yanira Bautista, NP
# ['Nurse Practitioner']
# 4000 Fulton St
# YBL5L3
# 354C4259-334C-0000-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77009
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# John McDivitt, NP
# ['Nurse Practitioner']
# 10705 Spring Grn Blvd Ste 200
# VPJCWGU899
# 434A5056-4757-3855-3939-000000000000
# Houston
# Houston, TX
# Houston, TX 77096
# https://photos.healthgrades.com/img/silhouettes/silhouette-male_w60h80_v1.jpg
# Stephanie Frimpong-Badu, FNP
# ['Nurse Practitioner']
# 5656 Kelley 80001 St Ste 2lb
# OYYVYM7
# 5659594F-4D59-0037-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77026
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Carrie Middlebrooks, RN
# ['Nurse Practitioner']
# 6621 Fannin St Mc Ste 19345c-19345h
# UMJAFA6755
# 414A4D55-4146-3736-3535-000000000000
# Houston
# Houston, TX
# Houston, TX 77030
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Jennifer Maupin, CPNP
# ['Pediatric Nurse Practitioner', 'Nurse Practitioner']
# 6701 Fannin St CCC # 1720.11
# C61J5BL136
# 4A313643-4235-314C-3336-000000000000
# Houston
# Houston, TX
# Houston, TX 77030
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Michael Pudlo, ACNP-BC
# ['Nurse Practitioner']
# 6445 Main Street Opc # 26
# UAFQFXI194
# 51464155-5846-3149-3934-000000000000
# Houston
# Houston, TX
# Houston, TX 77030
# https://photos.healthgrades.com/img/silhouettes/silhouette-male_w60h80_v1.jpg
# Nizar Moughrabi, NP
# ['Nurse Practitioner']
# 7401 S Main Fondren Orthopedic P
# DFHBT3U625
# 42484644-3354-3655-3235-000000000000
# Houston
# Houston, TX
# Houston, TX 77030
# https://photos.healthgrades.com/img/silhouettes/silhouette-male_w60h80_v1.jpg
# Dr. Roseline Okoro, DNP
# ['Nurse Practitioner', 'Family Practitioner']
# 3803 Irvington Blvd
# OONK68K
# 4B4E4F4F-3836-004B-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77009
# https://photos.healthgrades.com/img/prov/3/8/2/382KC_w60h80_v12928.jpg
# Lee Stockton, NP
# ['Nurse Practitioner']
# 1431 Studemont St Ste C2400
# S7W6EZ9383
# 36573753-5A45-3339-3833-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# https://photos.healthgrades.com/img/prov/x/2/r/x2rby_w60h80_vSyMAocWepI.jpg
# Hernan Martinez, ARNP
# ['Nurse Practitioner']
# 1315 St Joseph Pkwy Ste 1309
# OOO88CB
# 384F4F4F-4338-0042-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# https://photos.healthgrades.com/img/silhouettes/silhouette-male_w60h80_v1.jpg
# Alyssa Yow, NP
# ['Nurse Practitioner']
# 1934 CAROLINE ST
# LHN9ZXD799
# 394E484C-585A-3744-3939-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Delisa Mitchell, CPNP
# ['Pediatric Nurse Practitioner', 'Nurse Practitioner']
# 2101 Crawford St Ste 115
# 1EVU84RV07
# 55564531-3438-5652-3037-000000000000
# Houston
# Houston, TX
# Houston, TX 77002
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Cindy Campos
# ['Nurse Practitioner']
# 4302 Center St
# OOJ9V7C
# 394A4F4F-3756-0043-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Christelle Hernandez, NP
# ['Nurse Practitioner']
# 3811 Lyons Ave
# OYXWMB7
# 5758594F-424D-0037-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77020
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Peter Dagher, FNP-C
# ['Nurse Practitioner']
# 4500 Washington Ave Ste 300
# V6DECVY944
# 45443656-5643-3959-3434-000000000000
# Houston
# Houston, TX
# Houston, TX 77007
# https://photos.healthgrades.com/img/silhouettes/silhouette-male_w60h80_v1.jpg
# Meagan Chavarria, NP
# ['Critical Care Medicine Specialist', 'Cardiology Specialist', 'Nurse Practitioner']
# 6565 Fannin St Fondren # 270
# 19T3ILIT67
# 33543931-4C49-5449-3637-000000000000
# Houston
# Houston, TX
# Houston, TX 77030
# https://photos.healthgrades.com/img/prov/X/Y/L/XYLFCFB_w60h80_v49416.jpg
# Mary Shepard, APN
# ['Nurse Practitioner']
# 1415 California St
# OO7FS2D
# 46374F4F-3253-0044-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77006
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Christine Farley, PMHNP
# ['Nurse Practitioner']
# 1415 California St
# OO8963Q
# 39384F4F-3336-0051-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77006
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg
# Andrea Armstrong, RN
# ['Nurse Practitioner']
# 925 N Shepherd Dr
# OOR968W
# 39524F4F-3836-0057-0000-000000000000
# Houston
# Houston, TX
# Houston, TX 77008
# https://photos.healthgrades.com/img/silhouettes/silhouette-female_w60h80_v1.jpg

# %%
#

# %%
import pandas as pd
data_all=[]
for dentist in dentists:
  doctor_name = dentist['displayName']
  specialty = "Family Practitioner" #print(dentist['specialistDesc'])
  address =dentist['addresses'][0]['address1']
  officeCode = dentist['addresses'][0]['officeCode']
  officeGuid = dentist['addresses'][0]['officeGuid']
  cityName =dentist['addresses'][0]['location']['cityName']
  cityAndState = dentist['addresses'][0]['location']['cityAndState']
  cityStateZipBestMatch = dentist['addresses'][0]['location']['cityStateZipBestMatch']
  images = 'https:'+dentist['images'][0]['url']
  data_all.append({'Doctor Name':doctor_name,'Specialty':specialty,'Address': address, 'OfficeCode': officeCode, 'OfficeGuid': officeGuid, 'CityName': cityName, 'CityAndState': cityAndState, 'CityStateZipBestMatch':cityStateZipBestMatch, 'Images': images})
df = pd.DataFrame(data_all)
df.to_csv('products1.csv',encoding='utf-8')
  # print(dentist['addresses'][0]['location']['cityName']['cityAndState'])
  # print(dentist['addresses'][0]['location']['cityName']['cityStateZipBestMatch'])

# %%
#

# %%
#

# %%
#
